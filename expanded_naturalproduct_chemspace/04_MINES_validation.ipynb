# %% [markdown]
# # Search for known compounds

# %% [markdown]
# With the database MetaCyc <https://metacyc.org/> the generated "predicted compounds" will be searched.

# %%
import requests
from bs4 import BeautifulSoup
import pymongo
import polars as pl
from tqdm import tqdm
from pymongo import MongoClient
import defl as defl
import urllib.parse

# %% [markdown]
# ## MongoDB

# %%
# %%time

# MongoDB connection
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["lotus_mines_enzymatic"]
compounds_collection = db["compounds"]

# Function to search MetaCyc
def search_metacyc(compound_name):
    search_url = "https://metacyc.org/compound?type=NIL&object="
    response = requests.get(search_url + compound_name)
    
    if response.status_code == 200:
        return response.text
    else:
        return None

# Function to extract SMILES from MetaCyc HTML content
def extract_smiles(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    smiles_tag = soup.find('td', text='SMILES')
    
    if smiles_tag:
        smiles_value = smiles_tag.find_next_sibling('td').text.strip()
        return smiles_value
    else:
        return None

# Function to process each compound
def process_compound(compound):
    compound_type = compound.get("type")
    
    # Only process if the compound's type is "Predicted"
    if compound_type != "Predicted":
        return None
    
    # Search MetaCyc for the compound
    html_content = search_metacyc(compound["name"])
    
    if html_content:
        smiles = extract_smiles(html_content)
        return smiles
    else:
        return None

# Main script
if __name__ == "__main__":
    results = []

    # Retrieve compounds from MongoDB
    compounds = compounds_collection.find({})
    
    # Use tqdm to display a progress bar
    for compound in tqdm(compounds, desc="Processing Compounds", unit=" compound"):
        smiles = process_compound(compound)
        if smiles:
            results.append({
                "Compound_id": compound["_id"],
                "SMILES": smiles,
                "InChI_key": compound["InChI_key"]
            })
# Out:
# Processing Compounds: 3432312compound [00:15, 226615.09compound/s]
# CPU times: user 12.1 s, sys: 661 ms, total: 12.8 s
# Wall time: 15.4 s

# %%
# %%time

# MongoDB connection
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["lotus_mines_enzymatic"]
compounds_collection = db["compounds"]

# Function to search MetaCyc
def search_metacyc(compound_name):
    search_url = "https://metacyc.org/compound?type=NIL&object="
    response = requests.get(search_url + compound_name)
    
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error: Unable to retrieve data (status code {response.status_code}) for {compound_name}")
        return None

# Function to extract SMILES from MetaCyc HTML content
def extract_smiles(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    smiles_tag = soup.find('td', text='SMILES')
    
    if smiles_tag:
        smiles_value = smiles_tag.find_next_sibling('td').text.strip()
        return smiles_value
    else:
        print("SMILES string not found in the HTML content.")
        return None

# Function to process each compound
def process_compound(compound):
    compound_type = compound.get("type")
    
    # Only process if the compound's type is "Predicted"
    if compound_type != "Predicted":
        #print(f"Skipping {compound['InChI_key']} because it is not of type 'Predicted'.")
        return None
    
    # Search MetaCyc for the compound
    html_content = search_metacyc(compound["name"])
    
    if html_content:
        smiles = extract_smiles(html_content)
        return smiles
    else:
        return None

# Main script
if __name__ == "__main__":
    results = []

    # Retrieve compounds from MongoDB
    compounds = compounds_collection.find({})
    
    # Use tqdm to display a progress bar
    for compound in tqdm(compounds, desc="Processing Compounds", unit="compound"):
        smiles = process_compound(compound)
        if smiles:
            results.append({
                "Compound_id": compound["_id"],
                "SMILES": smiles,
                "InChI_key": compound["InChI_key"]
            })

    print(results)
# Out:
# Processing Compounds: 3432312compound [00:15, 225981.74compound/s]
# []
# CPU times: user 12.3 s, sys: 276 ms, total: 12.6 s
# Wall time: 15.2 s

# %%
# Convert results to a Polars DataFrame
df = pl.DataFrame(results)

# Save the DataFrame to a file or further processing
#df.write_csv("metacyc_results.csv")
print(df)
# Out:
# shape: (0, 0)
# ┌┐
# ╞╡
# └┘

# %% [markdown]
# ### lookup predicted compounds in pubchem

# %%
# %%time

# load Inputfile
df_input_mines = pl.read_csv("../data/MINES/230106_frozen_metadata_inchy_smile.csv")
df_input_mines = df_input_mines.rename({"id":"InChI_key_lotus", "smiles":"smiles_lotus"})

df_input_mines.head(10)
# Out:
# CPU times: user 94.7 ms, sys: 13.3 ms, total: 108 ms
# Wall time: 6.53 ms
# shape: (10, 2)
# ┌─────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ InChI_key_lotus             ┆ smiles_lotus                                                       │
# │ ---                         ┆ ---                                                                │
# │ str                         ┆ str                                                                │
# ╞═════════════════════════════╪════════════════════════════════════════════════════════════════════╡
# │ XJOOMMHNYOJWCZ-UKRRQHHQSA-N ┆ CC1=C[C@@H]2c3cccc4[nH]cc(c34)C[C@H]2N(C)C1                        │
# │ SFCYVTIQMNZUCZ-UHFFFAOYSA-N ┆ C=C(C)C#Cc1cc(C=O)ccc1O                                            │
# │ OYZXDVPSGCKVOQ-UQBPGWFLSA-N ┆ COC(=O)[C@]12CCCC(C)(C)[C@@H]1CCc1cc(C(C)C)c(OC(C)=O)c(OC(C)=O)c12 │
# │ MSSOSOXUURLBHN-UHFFFAOYSA-N ┆ CCC(=O)OC1C2C(OC(=O)c3ccccc3)C34OC2(C)COC(=O)c2cccnc2C(C)C(C)C(=O) │
# │                             ┆ OC(C(O)C(OC(=O)c2ccccc2)C3(COC(C)=O)C1OC(C)=O)C4(C)O               │
# │ FNDJBOATFIWAJR-ONEGZZNKSA-N ┆ CC(C)=CCc1cc(/C=C/C=O)ccc1O                                        │
# │ CZUWIMDOXXXJRE-SHPISUKRSA-N ┆ CC(=O)OC/C=C(\C)CC[C@@H]1C(C)=CC[C@@H]2C(C)(C)C[C@H](O)C[C@@]12C   │
# │ FVNPLROTBAEWRZ-CMDGGOBGSA-N ┆ Cc1cnc(C)c(/C=C/c2ccccc2)n1                                        │
# │ CCHUDPANZXHQCS-UKTHLTGXSA-N ┆ CC(C)/C=C1/NC(=O)C(C(C)C)n2c1nc1c(c2=O)C=CC=CO1                    │
# │ VMVVAKUSEGPLKU-LRJCJXCVSA-N ┆ CCC[C@H](O)[C@@H](O)CCCCCCCC[C@@H](O)[C@H]1CC[C@H](CCCCCCCCCC[C@@H │
# │                             ┆ ](O)CC2=C[C@H](C)OC2=O)O1                                          │
# │ RYAHFDNUSMNPRF-UHFFFAOYSA-N ┆ C=C1C=Cc2cc(COC(=O)CCCCCCCC=CCCCCCCCC)ccc2OC1                      │
# └─────────────────────────────┴────────────────────────────────────────────────────────────────────┘

# %%
# %%time

# connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['compounds']

result = client['lotus_mines_enzymatic']['compounds'].find()

documents_list = list(result)

df_mongo = pl.DataFrame(documents_list)
df_mongo = df_mongo.drop(["Generation", "Expand", "Reactant_in", "Product_of", "Type"])
df_mongo = df_mongo.rename({"_id":"_id_mongo", 
                            "ID":"ID_mongo", 
                            "SMILES":"SMILES_mongo", 
                            "InChI_key":"InChI_key_mongo"})

df_mongo
# Out:
# CPU times: user 47.8 s, sys: 14 s, total: 1min 1s
# Wall time: 1min 4s
# shape: (3_432_312, 4)
# ┌────────────────────────┬────────────────────────┬────────────────────────┬───────────────────────┐
# │ _id_mongo              ┆ ID_mongo               ┆ SMILES_mongo           ┆ InChI_key_mongo       │
# │ ---                    ┆ ---                    ┆ ---                    ┆ ---                   │
# │ str                    ┆ str                    ┆ str                    ┆ str                   │
# ╞════════════════════════╪════════════════════════╪════════════════════════╪═══════════════════════╡
# │ Xed5e87faf61da02132a98 ┆ cpd00044               ┆ Nc1ncnc2c1ncn2C1OC(COP ┆ GACDQMDRPRGCTN        │
# │ 18e3222bb6d558f8258    ┆                        ┆ (=O)(O)OS(=O)(=O)O)C(O ┆                       │
# │                        ┆                        ┆ P(=O)(O)O)C1O          ┆                       │
# │ X73bc8ef21db580aefe4db ┆ cpd00001               ┆ O                      ┆ XLYOFNOQVPJJNP        │
# │ c0af17d4013961d9d17    ┆                        ┆                        ┆                       │
# │ Xf4a7855630639e93324ef ┆ cpd00202               ┆ CC(C)=CCOP(=O)(O)OP(=O ┆ CBIDRCWHNCKSTO        │
# │ bcfa9adb1b6a80e8b62    ┆                        ┆ )(O)O                  ┆                       │
# │ Xc4b3110bfc6e3fde007ae ┆ cpd00004               ┆ NC(=O)C1=CN(C2OC(COP(= ┆ BOPGDPNILDQYTO        │
# │ 1eefdda16eacf8fe948    ┆                        ┆ O)(O)OP(=O)(O)OCC3OC(n ┆                       │
# │                        ┆                        ┆ 4cnc5c(N)ncnc54)C(O)C3 ┆                       │
# │                        ┆                        ┆ O)C(O)C2O)C=CC1        ┆                       │
# │ X97b638f57607ff4202482 ┆ cpd00003               ┆ NC(=O)c1ccc[n+](C2OC(C ┆ BAWFJGJZGIEFAR        │
# │ 6314564b47adb4cf4cb    ┆                        ┆ OP(=O)(O)OP(=O)(O)OCC3 ┆                       │
# │                        ┆                        ┆ OC(n4cnc5c(N)ncnc54)C( ┆                       │
# │                        ┆                        ┆ O)C3O)C(O)C2O)c1       ┆                       │
# │ Xca3125292d42b5595b656 ┆ cpd00019               ┆ Nc1ncnc2c1ncn2C1OC(CSC ┆ ZJUKTBDSGOFHSH        │
# │ 96d5cd74e007b886297    ┆                        ┆ CC(N)C(=O)O)C(O)C1O    ┆                       │
# │ Xe264bf1bbd482e4369958 ┆ cpd00024               ┆ O=C(O)CCC(=O)C(=O)O    ┆ KPGXRSRHYNQIFN        │
# │ 55afdf2170ce7229f1d    ┆                        ┆                        ┆                       │
# │ Xad024c97bc6d1c83baf5d ┆ cpd00011               ┆ O=C=O                  ┆ CURLTUGMZLYLDI        │
# │ 8902af02c3a3db5358e    ┆                        ┆                        ┆                       │
# │ X8dc023d8052d83fb6fead ┆ cpd00007               ┆ O=O                    ┆ MYMOFIZGZYHOMD        │
# │ f8541387e57c199cad0    ┆                        ┆                        ┆                       │
# │ X9b5ec04e3e13766613e65 ┆ cpd00017               ┆ C[S+](CCC(N)C(=O)O)CC1 ┆ MEFKEPWMEQBLKI        │
# │ d29e9d5b275fd8a0317    ┆                        ┆ OC(n2cnc3c(N)ncnc32)C( ┆                       │
# │                        ┆                        ┆ O)C1O                  ┆                       │
# │ X87786109ddfaf26b1b2b7 ┆ cpd00023               ┆ N[C@@H](CCC(=O)O)C(=O) ┆ WHUUTDBJXJRKMK        │
# │ f94e186203ed53d02e0    ┆                        ┆ O                      ┆                       │
# │ X6ef144c58538460418b5f ┆ cpd00127               ┆ Oc1ccccc1              ┆ ISWSIDIOOBJBQZ        │
# │ 783f52c12e1ca82c965    ┆                        ┆                        ┆                       │
# │ X50d0c91f2e257f422cb9b ┆ cpd00022               ┆ CC(=O)SCCNC(=O)CCNC(=O ┆ ZSLZBFCDCINBPY        │
# │ 71e12354896d9d58af8    ┆                        ┆ )C(O)C(C)(C)COP(=O)(O) ┆                       │
# │                        ┆                        ┆ OP(=O)(O)OCC1OC(n2cnc3 ┆                       │
# │                        ┆                        ┆ c(N)ncnc32)C(O)C1OP(=O ┆                       │
# │                        ┆                        ┆ )(O)O                  ┆                       │
# │ X662c3c548e200875cdfe6 ┆ cpd00010               ┆ CC(C)(COP(=O)(O)OP(=O) ┆ RGJOEKWQDUBAIZ        │
# │ 560db6a67842229ae64    ┆                        ┆ (O)OCC1OC(n2cnc3c(N)nc ┆                       │
# │                        ┆                        ┆ nc32)C(O)C1OP(=O)(O)O) ┆                       │
# │                        ┆                        ┆ C(O)C(=O)NCCC(=O)NCCS  ┆                       │
# │ Xf1df8af9dcaa6d250a917 ┆ cpd09249               ┆ O=C(O)O                ┆ BVKZGUZCCUSVTD        │
# │ 743e94ae2a460ed3972    ┆                        ┆                        ┆                       │
# │ X7b260f891deab6862fb5c ┆ cpd00055               ┆ C=O                    ┆ WSFSSNUMVMOOMR        │
# │ 664fb7a7963f1b8d002    ┆                        ┆                        ┆                       │
# │ X05622481c18728cacf931 ┆ cpd00025               ┆ OO                     ┆ MHAJPDPJQMAIIY        │
# │ 7e9a57ce6d421315aac    ┆                        ┆                        ┆                       │
# │ X7cf0276e3b75d075bd908 ┆ cpd00045               ┆ Nc1ncnc2c1ncn2C1OC(COP ┆ WHTCPDAXWFLDIH        │
# │ c2b6d5fd66287f0fc1f    ┆                        ┆ (=O)(O)O)C(OP(=O)(O)O) ┆                       │
# │                        ┆                        ┆ C1O                    ┆                       │
# │ X69bd7ab90d3f972909c03 ┆ cpd00029               ┆ CC(=O)O                ┆ QTBSBXVTEAMEQO        │
# │ 8af169917ec6eb194ea    ┆                        ┆                        ┆                       │
# │ X55bf5fd4422ef2c60d4a2 ┆ cpd00936               ┆ CC(Nc1ccc(CC(O)C(O)C(O ┆ RMPHWTMYCVTPKB        │
# │ 1c6e46f51e9cc03b1b4    ┆                        ┆ )COC2OC(COP(=O)(O)OC(C ┆                       │
# │                        ┆                        ┆ CC(=O)O)C(=O)O)C(O)C2O ┆                       │
# │                        ┆                        ┆ )cc1)C1C(C)Nc2[nH]c(N) ┆                       │
# │                        ┆                        ┆ nc(=O)c2N1C=O          ┆                       │
# │ Xf9c340c28a21ce5b75e2d ┆ cpd00081               ┆ O=S(O)O                ┆ LSNNMFCWUKXFEE        │
# │ fde27f3094fe6829792    ┆                        ┆                        ┆                       │
# │ X229239fbd0f5bbca1a205 ┆ cpd00013               ┆ N                      ┆ QGZKDVFQNNGYKY        │
# │ 511590f79d473665988    ┆                        ┆                        ┆                       │
# │ X758ca2a2cbf4872ace1e8 ┆ cpd00009               ┆ O=P(O)(O)O             ┆ NBIIXXVUZAFLBC        │
# │ 8c2878217e8594d9245    ┆                        ┆                        ┆                       │
# │ Xa2a868d3f3866d6bfbbe7 ┆ cpd00012               ┆ O=P(O)(O)OP(=O)(O)O    ┆ XPPKVPWEQAFLFU        │
# │ 8b615e42f81511ebff8    ┆                        ┆                        ┆                       │
# │ X9eb6018447ca1476bb741 ┆ cpd00895               ┆ CC(Nc1ccc(CC(O)C(O)C(O ┆ SCBIBGUJSMHIAI        │
# │ d78058a711afc1f569c    ┆                        ┆ )COC2OC(COP(=O)(O)OC(C ┆                       │
# │                        ┆                        ┆ CC(=O)O)C(=O)O)C(O)C2O ┆                       │
# │                        ┆                        ┆ )cc1)C1Nc2c([nH]c(N)nc ┆                       │
# │                        ┆                        ┆ 2=O)NC1C               ┆                       │
# │ X731743cee49a2049f3c8c ┆ cpd00002               ┆ Nc1ncnc2c1ncn2C1OC(COP ┆ ZKHQWZAMYRWXGA        │
# │ 017ce750f23dcaab919    ┆                        ┆ (=O)(O)OP(=O)(O)OP(=O) ┆                       │
# │                        ┆                        ┆ (O)O)C(O)C1O           ┆                       │
# │ X110bff0e0028ae979d204 ┆ cpd00071               ┆ CC=O                   ┆ IKHGUXGNUITLKF        │
# │ 53f27e0c842030880cc    ┆                        ┆                        ┆                       │
# │ X7a392897eb77992af7ea5 ┆ cpd00113               ┆ C=C(C)CCOP(=O)(O)OP(=O ┆ NUHSROFQTUXZQQ        │
# │ 5434e80925dc8c681eb    ┆                        ┆ )(O)O                  ┆                       │
# │ X9c29f84930a190d9086a4 ┆ cpd00008               ┆ Nc1ncnc2c1ncn2C1OC(COP ┆ XTWYTFMLZFPYCI        │
# │ 6c344020283c85fb917    ┆                        ┆ (=O)(O)OP(=O)(O)O)C(O) ┆                       │
# │                        ┆                        ┆ C1O                    ┆                       │
# │ X572ac7273559de6a8b076 ┆ cpd00359               ┆ c1ccc2[nH]ccc2c1       ┆ SIKJAQJRHWYJAI        │
# │ 94650a211410980510b    ┆                        ┆                        ┆                       │
# │ X2afb0d1241a06a5b42485 ┆ cpd00018               ┆ Nc1ncnc2c1ncn2C1OC(COP ┆ UDMBCSSLTHHNCD        │
# │ c9533e1ee325f9c9c21    ┆                        ┆ (=O)(O)O)C(O)C1O       ┆                       │
# │ X0eb45233dd43ecacb9fb1 ┆ cpd00067               ┆ [H+]                   ┆ GPRLSGONYQIRFK        │
# │ e31140450e1dace01c5    ┆                        ┆                        ┆                       │
# │ X0ea9546187e45fbb47e04 ┆ cpd00119               ┆ NC(Cc1c[nH]cn1)C(=O)O  ┆ HNDVDQJCIGZPNO        │
# │ 66c75193007351c34db    ┆                        ┆                        ┆                       │
# │ Ccb4bbce54cc03da8afe00 ┆ XJOOMMHNYOJWCZ-UKRRQHH ┆ CC1=CC2c3cccc4[nH]cc(c ┆ XJOOMMHNYOJWCZ-UHFFFA │
# │ 90e2869252ff6cb7aa8    ┆ QSA-N                  ┆ 34)CC2N(C)C1           ┆ OYSA-N                │
# │ C64d6d2fef30e6e42986c2 ┆ SFCYVTIQMNZUCZ-UHFFFAO ┆ C=C(C)C#Cc1cc(C=O)ccc1 ┆ SFCYVTIQMNZUCZ-UHFFFA │
# │ a1e36a719d69c2a2030    ┆ YSA-N                  ┆ O                      ┆ OYSA-N                │
# │ Cacd119678c4c728e090ae ┆ MSSOSOXUURLBHN-UHFFFAO ┆ CCC(=O)OC1C2C(OC(=O)c3 ┆ MSSOSOXUURLBHN-UHFFFA │
# │ 999c931ca0085876ef3    ┆ YSA-N                  ┆ ccccc3)C34OC2(C)COC(=O ┆ OYSA-N                │
# │                        ┆                        ┆ )c2cccnc2C(C)C(C)C(=O) ┆                       │
# │                        ┆                        ┆ OC(C(O)C(OC(=O)c2ccccc ┆                       │
# │                        ┆                        ┆ 2)C3(COC(C)=O)C1OC(C)= ┆                       │
# │                        ┆                        ┆ O)C4(C)O               ┆                       │
# │ C86f7988222caa340261bd ┆ CCHUDPANZXHQCS-UKTHLTG ┆ CC(C)C=C1NC(=O)C(C(C)C ┆ CCHUDPANZXHQCS-UHFFFA │
# │ c7fda8231cbad1598b4    ┆ XSA-N                  ┆ )n2c1nc1c(c2=O)C=CC=CO ┆ OYSA-N                │
# │                        ┆                        ┆ 1                      ┆                       │
# │ C9f9c52031affb165344c9 ┆ OYZXDVPSGCKVOQ-UQBPGWF ┆ COC(=O)[C@]12CCCC(C)(C ┆ OYZXDVPSGCKVOQ-UQBPGW │
# │ cef3116d1681868d8c0    ┆ LSA-N                  ┆ )[C@@H]1CCc1cc(C(C)C)c ┆ FLSA-N                │
# │                        ┆                        ┆ (OC(C)=O)c(OC(C)=O)c12 ┆                       │
# │ C1de9654ff313d8cd6a485 ┆ FNDJBOATFIWAJR-ONEGZZN ┆ CC(C)=CCc1cc(/C=C/C=O) ┆ FNDJBOATFIWAJR-ONEGZZ │
# │ a80ee0b955d5ede1050    ┆ KSA-N                  ┆ ccc1O                  ┆ NKSA-N                │
# │ …                      ┆ …                      ┆ …                      ┆ …                     │
# │ Cfd801cfa9bebe477472e3 ┆ pkc3251912             ┆ CCCCCCCCCCCCCCC(O)CC(O ┆ RXMUISOIJWKKIF-UHFFFA │
# │ 4eeeebae6cd169e8c66    ┆                        ┆ )C(COC1OC(CO)C(O)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ 1O)NC(=O)C(O)CCCC(O)CC ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C8ddc1c132e447b6825c16 ┆ pkc1820413             ┆ CCCCCCCCCCCCCCC(O)CC(O ┆ MVCPLFLOTLZHKV-UHFFFA │
# │ 8cfe59503c2e5fce484    ┆                        ┆ )C(COC1OC(CO)C(O)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ 1O)NC(=O)C(O)CCCCC(O)C ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C404db71ab0e059a40bbdb ┆ pkc0824390             ┆ CCCCCCCCCCCCCCC(O)CCC( ┆ VMCPSUDQJZDIGS-UHFFFA │
# │ 0a45ebcd01da2be3a55    ┆                        ┆ O)C(=O)NC(COC1OC(CO)C( ┆ OYSA-N                │
# │                        ┆                        ┆ O)C(O)C1O)C(O)CC(O)CCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C872462c864386b6c6c5a9 ┆ pkc1734374             ┆ CCCCCCCCCCCCCCCC(O)CC( ┆ DLYLXGMLCPHSKB-UHFFFA │
# │ cb874bda01c3499f27a    ┆                        ┆ O)C(=O)NC(COC1OC(CO)C( ┆ OYSA-N                │
# │                        ┆                        ┆ O)C(O)C1O)C(O)CC(O)CCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C194f646c8c15f82977d4d ┆ pkc0324292             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ DUKMULWOIVPSKP-UHFFFA │
# │ 0c5af087a3e94d3d653    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)C(O)C(O)CCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C7cda97314ea08ace2829f ┆ pkc1602234             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ CYHQYQNIPDLGKA-CQZNJP │
# │ f7615b2ab8cf540e5be    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ GMSA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](O)[C@@ ┆                       │
# │                        ┆                        ┆ H](O)C(=O)[C@H](C)C[C@ ┆                       │
# │                        ┆                        ┆ H](C)/C=C\C=CC=C(C)[C@ ┆                       │
# │                        ┆                        ┆ @H](O)C[C@H]3CC[C@@H]( ┆                       │
# │                        ┆                        ┆ C)[C@](O)(CC(=O)N4CCC( ┆                       │
# │                        ┆                        ┆ O)C[C@H]4C(=O)O2)O3)CC ┆                       │
# │                        ┆                        ┆ [C@H]1O                ┆                       │
# │ C08bc6075b66703cbfb2e7 ┆ pkc0112405             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ LKLKYJHDSOPSAM-UHFFFA │
# │ 3a55e8ec25916ffe9ee    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)C(O)CC ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C82cbed7e3bdf78e40a69a ┆ pkc1678876             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ XYCUNEIUUSPBMO-UHFFFA │
# │ a4704f3f05d567d33cd    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCC(O) ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C4a898472d5160af29a3df ┆ pkc0956259             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ GLNOOIANNDHVKL-UHFFFA │
# │ e8907305790b6840d85    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CC(O)C ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ Ccb5f13ad0b0973ffc2822 ┆ pkc2608598             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ YETOWZUDRMJVNH-UHFFFA │
# │ aca6cc29dac66d6b64f    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCC(O ┆                       │
# │                        ┆                        ┆ )CCCCCCCCCC            ┆                       │
# │ C293e23a989f9cb08b45aa ┆ pkc0528892             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ NNPMRJUADADWBV-UHFFFA │
# │ 148fa2a40bd6b823bf0    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCCC( ┆                       │
# │                        ┆                        ┆ O)CCCCCCCCC            ┆                       │
# │ C63ee93c044fc3e5c8f463 ┆ pkc1282216             ┆ C/C(=C\C(=O)OC[C@H]1O[ ┆ FFSHOPRZKOKMKA-TWNQFI │
# │ e9baca1756bc55b3d20    ┆                        ┆ C@@H](Oc2c(C)occc2=O)[ ┆ QASA-N                │
# │                        ┆                        ┆ C@H](O)[C@@H](O)[C@@H] ┆                       │
# │                        ┆                        ┆ 1O)c1ccc(O)cc1         ┆                       │
# │ C10a843e54bceea6132970 ┆ pkc0213642             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ RXDXPXKJQUDVNC-UHFFFA │
# │ 57433e237b0853c0af2    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCCCC ┆                       │
# │                        ┆                        ┆ C(O)CCCCCCC            ┆                       │
# │ C19aa5dcee3c2cb4002457 ┆ pkc0328843             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ FBHZTAJFWNRENK-UHFFFA │
# │ 27b364f8bf1718e906d    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCCCC ┆                       │
# │                        ┆                        ┆ CC(O)CCCCCC            ┆                       │
# │ C8ae27de265d8f630e0d59 ┆ pkc1782487             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ LUMJEYWFLQJCLP-UHFFFA │
# │ 7bd67d2d198cf638e68    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCCCC ┆                       │
# │                        ┆                        ┆ CCC(O)CCCCC            ┆                       │
# │ C7c2ec049858f212b9986c ┆ pkc1593562             ┆ CO[C@H]1C[C@H]2CC[C@@H ┆ YWKYZIAJODSFRT-YMWUSC │
# │ 955d46910a44cefa144    ┆                        ┆ ](C)[C@](O)(CC(=O)N3CC ┆ JJSA-N                │
# │                        ┆                        ┆ CC[C@H]3C(=O)O[C@@H]([ ┆                       │
# │                        ┆                        ┆ C@H](C)C[C@@H]3CC[C@@H ┆                       │
# │                        ┆                        ┆ ](O)[C@@H](OC)C3)CC(=O ┆                       │
# │                        ┆                        ┆ )[C@H](C)/C=C(/C)[C@@H ┆                       │
# │                        ┆                        ┆ ](O)[C@@H](O)C(=O)[C@H ┆                       │
# │                        ┆                        ┆ ](C)C[C@H](C)/C=C\C=CC ┆                       │
# │                        ┆                        ┆ =C1C)O2                ┆                       │
# │ Cd180323ac2649bc6f9ae9 ┆ pkc2687022             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ MNGZJNGBHOAGLA-LGPZNQ │
# │ a74eb52b2e3fa164bf0    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ STSA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](O)[C@@ ┆                       │
# │                        ┆                        ┆ H](O)C(=O)[C@H](C)C[C@ ┆                       │
# │                        ┆                        ┆ H](C)/C=C\C=CC(C)=C(C) ┆                       │
# │                        ┆                        ┆ [C@@H](O)C[C@H]3CC[C@@ ┆                       │
# │                        ┆                        ┆ H](C)[C@](O)(CC(=O)N4C ┆                       │
# │                        ┆                        ┆ CCC[C@H]4C(=O)O2)O3)CC ┆                       │
# │                        ┆                        ┆ [C@H]1O                ┆                       │
# │ Ce5806cf8bdc34263b8c4e ┆ pkc2943673             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ AGGCFOLVQBJTJO-UHFFFA │
# │ 7c719f4af30ab494bd7    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCCCC ┆                       │
# │                        ┆                        ┆ CCCCCCC(C)O            ┆                       │
# │ C46bac503680b158aeace1 ┆ pkc0907063             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ JKSLBFRPNPWFES-WRENDS │
# │ 980649aa9acce68be89    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ OASA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](O)[C@@ ┆                       │
# │                        ┆                        ┆ H](O)C(=O)[C@H](C)C[C@ ┆                       │
# │                        ┆                        ┆ H](C)/C=C\C=CC=C(C)[C@ ┆                       │
# │                        ┆                        ┆ @H](O)C[C@H]3CC[C@@H]( ┆                       │
# │                        ┆                        ┆ C)[C@](O)(CC(=O)N4CCCC ┆                       │
# │                        ┆                        ┆ [C@H]4C(=O)O2)O3)CC[C@ ┆                       │
# │                        ┆                        ┆ H]1OC                  ┆                       │
# │ Cc008c0d6c8e0ad75b79ad ┆ pkc2463791             ┆ CCCCCCCCCCCCCCCCCC(OC) ┆ CYGYULRISVDXIT-UHFFFA │
# │ f31cced8b51c7e79d72    ┆                        ┆ C(=O)NC(COC1OC(CO)C(O) ┆ OYSA-N                │
# │                        ┆                        ┆ C(O)C1O)C(O)CC(O)CCCCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCC              ┆                       │
# │ C38f489ccc2774803ca42f ┆ pkc0730496             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ SHTLGTDHXZOZNA-UHFFFA │
# │ 828001b794a895e309c    ┆                        ┆ (=O)N(C)C(COC1OC(CO)C( ┆ OYSA-N                │
# │                        ┆                        ┆ O)C(O)C1O)C(O)CC(O)CCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C48f71cad409a0810cc498 ┆ pkc0935990             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ ODDYRMKTPOYICZ-UHFFFA │
# │ 56900fb628432070fd8    ┆                        ┆ (=O)NC(COC1OC(COC)C(O) ┆ OYSA-N                │
# │                        ┆                        ┆ C(O)C1O)C(O)CC(O)CCCCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCC              ┆                       │
# │ C1f5274d8c252c0a0134fc ┆ pkc0401134             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ YXESBGFXTFMADG-UHFFFA │
# │ a980043b93bd7d34b7c    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1OC)C(O)CC(O)CCCCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCC              ┆                       │
# │ Cfc8ea7ec975a9236dd515 ┆ pkc3239876             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ HPSBOQZNRNRAGJ-REDJND │
# │ 8d8d2b905c2e6fa7a93    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ MYSA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](OP(=O) ┆                       │
# │                        ┆                        ┆ (O)O)[C@@H](O)C(=O)[C@ ┆                       │
# │                        ┆                        ┆ H](C)C[C@H](C)/C=C\C=C ┆                       │
# │                        ┆                        ┆ C=C(C)[C@@H](O)C[C@H]3 ┆                       │
# │                        ┆                        ┆ CC[C@@H](C)[C@](O)(CC( ┆                       │
# │                        ┆                        ┆ =O)N4CCCC[C@H]4C(=O)O2 ┆                       │
# │                        ┆                        ┆ )O3)CC[C@H]1O          ┆                       │
# │ Ce76ad5c7b8e0f00dcf5fe ┆ pkc2968288             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ CLBKEZPPJVTWPE-UHFFFA │
# │ a6e76759a61b3de02f1    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (OC)C1O)C(O)CC(O)CCCCC ┆                       │
# │                        ┆                        ┆ CCCCCCCCC              ┆                       │
# │ C09113622451c54ea43878 ┆ pkc0116685             ┆ Cc1occc(=O)c1O[C@@H]1O ┆ JQAHSNCGCALSPP-LTBYZH │
# │ caa26ae31885721b73d    ┆                        ┆ [C@H](COC(=O)/C=C/c2cc ┆ LZSA-N                │
# │                        ┆                        ┆ c(O)cc2)[C@@H](O)[C@H] ┆                       │
# │                        ┆                        ┆ (OS(=O)(=O)O)[C@H]1O   ┆                       │
# │ C1bc4042493c0a2effd34d ┆ pkc0355877             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ MMCONNFAGNFCMW-UHFFFA │
# │ facbd28e32059e4e8fc    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(CC(O)CCCCCCCC ┆                       │
# │                        ┆                        ┆ CCCCCC)OC              ┆                       │
# │ C816389056191bed0e5cf7 ┆ pkc1660680             ┆ CCCCCCCCCCCCCCCCCC(OP( ┆ QXVTZKPCTOQYKX-UHFFFA │
# │ 702494fb909141af164    ┆                        ┆ =O)(O)O)C(=O)NC(COC1OC ┆ OYSA-N                │
# │                        ┆                        ┆ (CO)C(O)C(O)C1O)C(O)CC ┆                       │
# │                        ┆                        ┆ (O)CCCCCCCCCCCCCC      ┆                       │
# │ C3b5bdb0c03ee28cc4ce59 ┆ pkc0761340             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ KHKUYCWKJBZJFK-UHFFFA │
# │ f50d320bfbab5e42c9c    ┆                        ┆ (=O)NC(COC1OC(COP(=O)( ┆ OYSA-N                │
# │                        ┆                        ┆ O)O)C(O)C(O)C1O)C(O)CC ┆                       │
# │                        ┆                        ┆ (O)CCCCCCCCCCCCCC      ┆                       │
# │ C21f10d88c43660d7ee22b ┆ pkc0434629             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ IEJYHSYRIDVVKG-LAFZTG │
# │ 6c2a60e533d62b04f6b    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ LBSA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](O)[C@@ ┆                       │
# │                        ┆                        ┆ H](O)C(=O)[C@H](C)C[C@ ┆                       │
# │                        ┆                        ┆ H](C)/C=C\C=CC=C(C)[C@ ┆                       │
# │                        ┆                        ┆ @H](O)C[C@H]3CC[C@@H]( ┆                       │
# │                        ┆                        ┆ C)[C@](O)(CC(=O)N4CCCC ┆                       │
# │                        ┆                        ┆ [C@H]4C(=O)O2)O3)CC[C@ ┆                       │
# │                        ┆                        ┆ H]1OP(=O)(O)O          ┆                       │
# │ Cb3cf132a81b5014fd8023 ┆ pkc2306574             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ CHVYHLXVBRFULD-LAFZTG │
# │ 18ba821bd14fefac51e    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ LBSA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](O)[C@@ ┆                       │
# │                        ┆                        ┆ H](O)C(=O)[C@H](C)C[C@ ┆                       │
# │                        ┆                        ┆ H](C)/C=C\C=CC=C(C)[C@ ┆                       │
# │                        ┆                        ┆ @H](O)C[C@H]3CC[C@@H]( ┆                       │
# │                        ┆                        ┆ C)[C@](O)(CC(=O)N4CCCC ┆                       │
# │                        ┆                        ┆ [C@H]4C(=O)O2)O3)CC[C@ ┆                       │
# │                        ┆                        ┆ H]1OS(=O)(=O)O         ┆                       │
# │ Cdc860375bebc9e2ba1078 ┆ pkc2828515             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ RPDVVLBXEJNLTA-FABZSU │
# │ e7c7921464406245cb4    ┆                        ┆ (C)[C@@H](C)OC(=O)[C@@ ┆ JCSA-N                │
# │                        ┆                        ┆ H]2CCCCN2C(=O)C[C@]2(O ┆                       │
# │                        ┆                        ┆ )O[C@@H](C[C@H](O)C(C) ┆                       │
# │                        ┆                        ┆ =CC=C/C=C\[C@@H](C)C[C ┆                       │
# │                        ┆                        ┆ @@H](C)C(=O)[C@H](O)[C ┆                       │
# │                        ┆                        ┆ @H](O)/C(C)=C\[C@@H](C ┆                       │
# │                        ┆                        ┆ )C(=O)O)CC[C@H]2C)CC[C ┆                       │
# │                        ┆                        ┆ @H]1O                  ┆                       │
# │ C7ff816ba011a36c3d3dfc ┆ pkc1642322             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ RSUDPKMYRZOKEB-UHFFFA │
# │ 52efd5e17a795b08e79    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1OP(=O)(O)O)C(O)CC ┆                       │
# │                        ┆                        ┆ (O)CCCCCCCCCCCCCC      ┆                       │
# │ Cb3ffbac2efab8ca4c3ab7 ┆ pkc2309035             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ UXJLNULSCNUGDG-UHFFFA │
# │ d90e219d0367f97bb47    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(CCCCCCCC ┆                       │
# │                        ┆                        ┆ CCCCCC)OP(=O)(O)O      ┆                       │
# │ C7efb6b825d937a9a6be61 ┆ pkc1629679             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ XEZSBABZXBAXGJ-UHFFFA │
# │ 6b35c71840988faecdb    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (OS(=O)(=O)O)C1O)C(O)C ┆                       │
# │                        ┆                        ┆ C(O)CCCCCCCCCCCCCC     ┆                       │
# │ Cc337da8647460c268f3f2 ┆ pkc2504307             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ CVRGXGCPCBXRBW-UHFFFA │
# │ a9252e9d3a4f95cd6fd    ┆                        ┆ (=O)NC(COC1OC(CO)C(OS( ┆ OYSA-N                │
# │                        ┆                        ┆ =O)(=O)O)C(O)C1O)C(O)C ┆                       │
# │                        ┆                        ┆ C(O)CCCCCCCCCCCCCC     ┆                       │
# │ C5cfb2f225d08736522ee7 ┆ pkc1193046             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ LGTSLNCQWGZHKI-UHFFFA │
# │ cb328edf065a7b063cd    ┆                        ┆ (=O)NC(COC1OC(CO)C(O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1OS(=O)(=O)O)C(O)C ┆                       │
# │                        ┆                        ┆ C(O)CCCCCCCCCCCCCC     ┆                       │
# │ Ca428aa92d29c9bd847c2f ┆ pkc2105836             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ HZAOURVOPUZOOT-UHFFFA │
# │ 13b758062bd45c947ba    ┆                        ┆ (=O)NC(CO)C(O)CC(O)CCC ┆ OYSA-N                │
# │                        ┆                        ┆ CCCCCCCCCCC            ┆                       │
# │ C8b66734ec9cf5107e0665 ┆ pkc1788952             ┆ CCCCCCCCCCCCCCCCCC(O)C ┆ IORSVSFWGKORCR-UHFFFA │
# │ 8274f57809a42ae1f75    ┆                        ┆ (=O)NC(COC1OC(C)C(=O)C ┆ OYSA-N                │
# │                        ┆                        ┆ (O)C1O)C(O)CC(O)CCCCCC ┆                       │
# │                        ┆                        ┆ CCCCCCCC               ┆                       │
# │ C94da860af625d18c99fe3 ┆ pkc1910035             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ JJZFPINVRSTXLQ-RWHUPT │
# │ 5186b4566a475d02609    ┆                        ┆ (C)[C@@H](CC(=O)[C@H]( ┆ DWSA-N                │
# │                        ┆                        ┆ C)/C=C(/C)[C@@H](O)[C@ ┆                       │
# │                        ┆                        ┆ @H](O)C(=O)[C@H](C)C[C ┆                       │
# │                        ┆                        ┆ @H](C)/C=C\C=CC=C(C)[C ┆                       │
# │                        ┆                        ┆ @@H](O)C[C@H]2CC[C@@H] ┆                       │
# │                        ┆                        ┆ (C)[C@@](C)(O)O2)OC(=O ┆                       │
# │                        ┆                        ┆ )[C@@H]2CCCCN2C(=O)O)C ┆                       │
# │                        ┆                        ┆ C[C@H]1O               ┆                       │
# │ C1ae311798ae198421ee16 ┆ pkc0344632             ┆ C=C(CO)[C@@H]1Oc2ccc(C ┆ AGKOZCZSIZEZSL-RTKIRO │
# │ 16e7805fe6330f90c55    ┆                        ┆ (C)(O)CC(=O)O)cc2[C@H] ┆ INSA-N                │
# │                        ┆                        ┆ 1OC(C)=O               ┆                       │
# │ Cd04e41801d2fde5d74b9a ┆ pkc2671730             ┆ CC=C(CO)[C@@H]1Oc2ccc( ┆ INIDDKBKPNGARQ-JKSUJK │
# │ c55782c35b7e9bb9689    ┆                        ┆ C(C)=O)cc2[C@H]1OC(C)= ┆ DBSA-N                │
# │                        ┆                        ┆ O                      ┆                       │
# │ C444c9c393b7b601e39ee1 ┆ pkc0875900             ┆ C=C(COC)[C@@H]1Oc2ccc( ┆ WWFZLTOBQBFXRN-JKSUJK │
# │ 2f35c077d4df0cf3de1    ┆                        ┆ C(C)=O)cc2[C@H]1OC(C)= ┆ DBSA-N                │
# │                        ┆                        ┆ O                      ┆                       │
# │ Cad9797d84a560eeea111c ┆ pkc2226612             ┆ C=C(CO)[C@@H]1Oc2ccc(C ┆ OTHWZKRQZPQHOD-SXODRG │
# │ d3629b63dc34d323fd5    ┆                        ┆ (C)N)cc2[C@H]1OC(C)=O  ┆ RHSA-N                │
# │ C7f9d98a1d1c17e1707043 ┆ pkc1637859             ┆ CO[C@H]1C[C@H](C[C@@H] ┆ NVICSGKMRLVNNH-HIBRCN │
# │ 2bcc7f4efbb728d2b11    ┆                        ┆ (C)[C@H]2CC(=O)[C@H](C ┆ CNSA-N                │
# │                        ┆                        ┆ )/C=C(/C)[C@@H](O)C(=O ┆                       │
# │                        ┆                        ┆ )C(O)[C@H](C)C[C@H](C) ┆                       │
# │                        ┆                        ┆ /C=C\C=CC=C(C)[C@@H](O ┆                       │
# │                        ┆                        ┆ )C[C@H]3CC[C@@H](C)[C@ ┆                       │
# │                        ┆                        ┆ ](O)(CC(=O)N4CCCC[C@H] ┆                       │
# │                        ┆                        ┆ 4C(=O)O2)O3)CC[C@H]1O  ┆                       │
# │ C72b0d80fefdfac1dc63b9 ┆ pkc1471484             ┆ CC(=O)O[C@@H]1c2cc(C(C ┆ OQVATBXAYCGBOC-GRKKQI │
# │ 2f42fa0c50fcfcbe8d3    ┆                        ┆ )=O)ccc2O[C@H]1C(C)(O) ┆ SMSA-N                │
# │                        ┆                        ┆ CO                     ┆                       │
# │ C6ac0da3b68ea8c37f5ae3 ┆ pkc1369574             ┆ C=C(CO)[C@@H]1Oc2ccccc ┆ PZNUVJYFGSNVHU-QWHCGF │
# │ 46dc133657640206ca9    ┆                        ┆ 2[C@H]1OC(C)=O         ┆ SZSA-N                │
# │ C9a91fefcaf1fde95b661b ┆ pkc1983072             ┆ C=C(CO)[C@@H]1Oc2ccc(C ┆ GWGSNFOZYWDXLL-QWHCGF │
# │ e7bd02122d00165cc07    ┆                        ┆ (=O)O)cc2[C@H]1OC(C)=O ┆ SZSA-N                │
# │ C6c917c4bfaf9368310fed ┆ pkc1392894             ┆ C#Cc1ccc2c(c1)[C@@H](O ┆ JZNLCWCROXGVBX-LSDHHA │
# │ 1b6a351213c728d502b    ┆                        ┆ C(C)=O)[C@H](C(=C)CO)O ┆ IUSA-N                │
# │                        ┆                        ┆ 2                      ┆                       │
# │ Cecce4046440871add27df ┆ pkc3037284             ┆ C#CO[C@@H]1c2cc(C(C)=O ┆ HYBFSUJICCHNMB-LSDHHA │
# │ 1590b224853e1c13354    ┆                        ┆ )ccc2O[C@H]1C(=C)CO    ┆ IUSA-N                │
# └────────────────────────┴────────────────────────┴────────────────────────┴───────────────────────┘

# %%
df_starting = df_mongo.join(df_input_mines, left_on="ID_mongo", right_on="InChI_key_lotus", how="inner")

df_starting
# Out:
# shape: (147_861, 5)
# ┌───────────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ _id_mongo         ┆ ID_mongo          ┆ SMILES_mongo      ┆ InChI_key_mongo   ┆ smiles_lotus     │
# │ ---               ┆ ---               ┆ ---               ┆ ---               ┆ ---              │
# │ str               ┆ str               ┆ str               ┆ str               ┆ str              │
# ╞═══════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ Ccb4bbce54cc03da8 ┆ XJOOMMHNYOJWCZ-UK ┆ CC1=CC2c3cccc4[nH ┆ XJOOMMHNYOJWCZ-UH ┆ CC1=C[C@@H]2c3cc │
# │ afe0090e2869252ff ┆ RRQHHQSA-N        ┆ ]cc(c34)CC2N(C)C1 ┆ FFFAOYSA-N        ┆ cc4[nH]cc(c34)C[ │
# │ 6cb7aa8           ┆                   ┆                   ┆                   ┆ C@H]2N(C)C1      │
# │ C64d6d2fef30e6e42 ┆ SFCYVTIQMNZUCZ-UH ┆ C=C(C)C#Cc1cc(C=O ┆ SFCYVTIQMNZUCZ-UH ┆ C=C(C)C#Cc1cc(C= │
# │ 986c2a1e36a719d69 ┆ FFFAOYSA-N        ┆ )ccc1O            ┆ FFFAOYSA-N        ┆ O)ccc1O          │
# │ c2a2030           ┆                   ┆                   ┆                   ┆                  │
# │ Cacd119678c4c728e ┆ MSSOSOXUURLBHN-UH ┆ CCC(=O)OC1C2C(OC( ┆ MSSOSOXUURLBHN-UH ┆ CCC(=O)OC1C2C(OC │
# │ 090ae999c931ca008 ┆ FFFAOYSA-N        ┆ =O)c3ccccc3)C34OC ┆ FFFAOYSA-N        ┆ (=O)c3ccccc3)C34 │
# │ 5876ef3           ┆                   ┆ 2(C)COC(=O)c2cccn ┆                   ┆ OC2(C)COC(=O)c2c │
# │                   ┆                   ┆ c2C(C)C(C)C(=O)OC ┆                   ┆ ccnc2C(C)C(C)C(= │
# │                   ┆                   ┆ (C(O)C(OC(=O)c2cc ┆                   ┆ O)OC(C(O)C(OC(=O │
# │                   ┆                   ┆ ccc2)C3(COC(C)=O) ┆                   ┆ )c2ccccc2)C3(COC │
# │                   ┆                   ┆ C1OC(C)=O)C4(C)O  ┆                   ┆ (C)=O)C1OC(C)=O) │
# │                   ┆                   ┆                   ┆                   ┆ C4(C)O           │
# │ C86f7988222caa340 ┆ CCHUDPANZXHQCS-UK ┆ CC(C)C=C1NC(=O)C( ┆ CCHUDPANZXHQCS-UH ┆ CC(C)/C=C1/NC(=O │
# │ 261bdc7fda8231cba ┆ THLTGXSA-N        ┆ C(C)C)n2c1nc1c(c2 ┆ FFFAOYSA-N        ┆ )C(C(C)C)n2c1nc1 │
# │ 5a7e5f2           ┆                   ┆ C)C)C(C)(C)[C@](C ┆                   ┆ C(C)C)C(C)(C)[C@ │
# │                   ┆                   ┆ C=C(C)C)(C(=O)C(C ┆                   ┆ ](CC=C(C)C)(C(=O │
# │                   ┆                   ┆ (=O)c4ccc(O)c(O)c ┆                   ┆ )C(C(=O)c4ccc(O) │
# │                   ┆                   ┆ 4)=C2OC1(C)C)C3=O ┆                   ┆ c(O)c4)=C2OC1(C) │
# │                   ┆                   ┆                   ┆                   ┆ C)C3=O           │
# │ C0772d79302e4ba89 ┆ PHEWILLIAJUBQE-UV ┆ COc1cc(O)c2c(=O)c ┆ PHEWILLIAJUBQE-UV ┆ COc1cc(O)c2c(=O) │
# │ 5ba98b4e0675dc708 ┆ HBULKNSA-N        ┆ (O[C@@H]3O[C@H](C ┆ HBULKNSA-N        ┆ c(O[C@@H]3O[C@H] │
# │ eaccb73           ┆                   ┆ O)[C@H](O)[C@H](O ┆                   ┆ (CO)[C@H](O)[C@H │
# │                   ┆                   ┆ )[C@H]3O)c(-c3ccc ┆                   ┆ ](O)[C@H]3O)c(-c │
# │                   ┆                   ┆ (O)c(O)c3)oc2c1   ┆                   ┆ 3ccc(O)c(O)c3)oc │
# │                   ┆                   ┆                   ┆                   ┆ 2c1              │
# │ Ca097ebffa891c4d5 ┆ SEBKCRYGYKNELU-YH ┆ COc1c2c(cc3c1-c1c ┆ SEBKCRYGYKNELU-YH ┆ COc1c2c(cc3c1-c1 │
# │ ff499efba48947a12 ┆ TYYEMMSA-N        ┆ (cc4c(c1OC)OCO4)[ ┆ TYYEMMSA-N        ┆ c(cc4c(c1OC)OCO4 │
# │ 539e5ac           ┆                   ┆ C@@H](O)[C@H](C)[ ┆                   ┆ )[C@@H](O)[C@H]( │
# │                   ┆                   ┆ C@@H](C)C3=O)OCO2 ┆                   ┆ C)[C@@H](C)C3=O) │
# │                   ┆                   ┆                   ┆                   ┆ OCO2             │
# │ Ced98f1edb62a90b4 ┆ AVVUNMUZLDSORT-PN ┆ COC1CC/C=C(C)/C=C ┆ AVVUNMUZLDSORT-PN ┆ COC1CC/C=C(C)/C= │
# │ 6b3b4cf983a30045c ┆ OONDGPSA-N        ┆ /C(OC2CC(NC(C)=O) ┆ OONDGPSA-N        ┆ C/C(OC2CC(NC(C)= │
# │ 7182aa2           ┆                   ┆ C(O)C(C)O2)C(C)CC ┆                   ┆ O)C(O)C(C)O2)C(C │
# │                   ┆                   ┆ (OC)C2OC(O)(C(C)C ┆                   ┆ )CC(OC)C2OC(O)(C │
# │                   ┆                   ┆ (=O)OC1/C=C/C(C)= ┆                   ┆ (C)C(=O)OC1/C=C/ │
# │                   ┆                   ┆ C/C(C)C(C)O)C(OC) ┆                   ┆ C(C)=C/C(C)C(C)O │
# │                   ┆                   ┆ C(O)C2C           ┆                   ┆ )C(OC)C(O)C2C    │
# │ Cc90bf2abb2ad0d0d ┆ FAZJGQBGRJYILG-IU ┆ C[C@@]12CC[C@@H]3 ┆ FAZJGQBGRJYILG-IU ┆ C[C@@]12CC[C@@H] │
# │ 2ff0adc04595741ae ┆ CYTYENSA-N        ┆ [C@](C)(CC[C@@H]( ┆ CYTYENSA-N        ┆ 3[C@](C)(CC[C@@H │
# │ 506aa67           ┆                   ┆ O)[C@]3(C)CO)[C@H ┆                   ┆ ](O)[C@]3(C)CO)[ │
# │                   ┆                   ┆ ]1CC[C@H]1C(=CC[C ┆                   ┆ C@H]1CC[C@H]1C(= │
# │                   ┆                   ┆ @H]3[C@](C)(CO)[C ┆                   ┆ CC[C@H]3[C@](C)( │
# │                   ┆                   ┆ @H](O)CC[C@@]31C) ┆                   ┆ CO)[C@H](O)CC[C@ │
# │                   ┆                   ┆ C2                ┆                   ┆ @]31C)C2         │
# │ Cc0d3bebe660955df ┆ YBTAYKPEYLOHDQ-MI ┆ C/C(=C/CC/C(C)=C/ ┆ YBTAYKPEYLOHDQ-MI ┆ C/C(=C/CC/C(C)=C │
# │ 1a39376703a9ff789 ┆ CXRRPDSA-N        ┆ CCC1(C)CCc2cc(O)c ┆ CXRRPDSA-N        ┆ /CCC1(C)CCc2cc(O │
# │ eefc89d           ┆                   ┆ c(C)c2O1)C(=O)O   ┆                   ┆ )cc(C)c2O1)C(=O) │
# │                   ┆                   ┆                   ┆                   ┆ O                │
# │ C33503af38d84416c ┆ CLPJKIKSHFLLGR-RT ┆ Oc1ccc2c(c1)O[C@H ┆ CLPJKIKSHFLLGR-RT ┆ Oc1ccc2c(c1)O[C@ │
# │ a9ec3c04df4dae86b ┆ JSNJMCSA-N        ┆ ](c1ccc(O)c(O)c1) ┆ JSNJMCSA-N        ┆ H](c1ccc(O)c(O)c │
# │ da93aed           ┆                   ┆ [C@@H](O)[C@H]2c1 ┆                   ┆ 1)[C@@H](O)[C@H] │
# │                   ┆                   ┆ cc2c(cc1O)O[C@H]( ┆                   ┆ 2c1cc2c(cc1O)O[C │
# │                   ┆                   ┆ c1ccc(O)c(O)c1)[C ┆                   ┆ @H](c1ccc(O)c(O) │
# │                   ┆                   ┆ @@H](O)[C@@H]2O   ┆                   ┆ c1)[C@@H](O)[C@@ │
# │                   ┆                   ┆                   ┆                   ┆ H]2O             │
# │ Cbfe19512f451d906 ┆ XVXHJNWLSXMTBN-CA ┆ C=C(C(CC(O)C(C)(C ┆ XVXHJNWLSXMTBN-CA ┆ C=C(C(CC(O)C(C)( │
# │ 73fa3ef714f92a3ca ┆ BOIKOWSA-N        ┆ )O)OC(=O)/C(C)=C\ ┆ BOIKOWSA-N        ┆ C)O)OC(=O)/C(C)= │
# │ e196981           ┆                   ┆ C)[C@H]1C[C@H]2O[ ┆                   ┆ C\C)[C@H]1C[C@H] │
# │                   ┆                   ┆ C@@]2(C)C(OC(=O)/ ┆                   ┆ 2O[C@@]2(C)C(OC( │
# │                   ┆                   ┆ C(C)=C\C)[C@H]1OC ┆                   ┆ =O)/C(C)=C\C)[C@ │
# │                   ┆                   ┆ (C)=O             ┆                   ┆ H]1OC(C)=O       │
# │ C653b1aeca22dcf9c ┆ IXZYOWXVJDLODC-UH ┆ CC1OC(Oc2ccc3c(=O ┆ IXZYOWXVJDLODC-UH ┆ CC1OC(Oc2ccc3c(= │
# │ bb89b10b3ccf7b4b6 ┆ FFFAOYSA-N        ┆ )c(OC4OC(CO)C(O)C ┆ FFFAOYSA-N        ┆ O)c(OC4OC(CO)C(O │
# │ 6ff24d1           ┆                   ┆ (O)C4O)c(-c4ccccc ┆                   ┆ )C(O)C4O)c(-c4cc │
# │                   ┆                   ┆ 4)oc3c2)C(O)C(O)C ┆                   ┆ ccc4)oc3c2)C(O)C │
# │                   ┆                   ┆ 1O                ┆                   ┆ (O)C1O           │
# │ C93cd203c90afd932 ┆ PIRBWKHZKPMBQG-KA ┆ C/C=C(/C)C(=O)O[C ┆ PIRBWKHZKPMBQG-KA ┆ C/C=C(/C)C(=O)O[ │
# │ ad0787dc86a029d12 ┆ KNDSOOSA-N        ┆ @H]1C/C=C(\C)CC[C ┆ KNDSOOSA-N        ┆ C@H]1C/C=C(\C)CC │
# │ b873765           ┆                   ┆ @@H](C(C)C)[C@@H] ┆                   ┆ [C@@H](C(C)C)[C@ │
# │                   ┆                   ┆ (OC(C)=O)[C@H]2O[ ┆                   ┆ @H](OC(C)=O)[C@H │
# │                   ┆                   ┆ C@]12C            ┆                   ┆ ]2O[C@]12C       │
# │ C4a843adf9bbaf0c2 ┆ FCHVXNVDFYXLIL-UH ┆ CC12CC3(O)OC(O1)C ┆ FCHVXNVDFYXLIL-UH ┆ CC12CC3(O)OC(O1) │
# │ d688393942264cf0b ┆ FFFAOYSA-N        ┆ 1(COC(=O)c4ccc(O) ┆ FFFAOYSA-N        ┆ C1(COC(=O)c4ccc( │
# │ e3304f0           ┆                   ┆ cc4)C3CC21OC1OC(C ┆                   ┆ O)cc4)C3CC21OC1O │
# │                   ┆                   ┆ O)C(O)C(O)C1O     ┆                   ┆ C(CO)C(O)C(O)C1O │
# │ C17dd5cfc0fd4100f ┆ NDTDEVRGTYZRRA-QI ┆ CC(=O)CC[C@H]1C(C ┆ NDTDEVRGTYZRRA-QI ┆ CC(=O)CC[C@H]1C( │
# │ 4811f69818230ce52 ┆ LLFSRXSA-N        ┆ )=CC(=O)[C@H]2C(C ┆ LLFSRXSA-N        ┆ C)=CC(=O)[C@H]2C │
# │ 34978c6           ┆                   ┆ )(C)CCC[C@]12C    ┆                   ┆ (C)(C)CCC[C@]12C │
# │ C4ac091d67949a5f9 ┆ MKGZDUKUQPPHFM-LP ┆ CC[C@H](/C=C/[C@@ ┆ MKGZDUKUQPPHFM-LP ┆ CC[C@H](/C=C/[C@ │
# │ cc89a6eb26cce5de7 ┆ JPOILFSA-N        ┆ H](C)[C@H]1CC[C@H ┆ JPOILFSA-N        ┆ @H](C)[C@H]1CC[C │
# │ 7358ff4           ┆                   ┆ ]2[C@@H]3CCC4=CC( ┆                   ┆ @H]2[C@@H]3CCC4= │
# │                   ┆                   ┆ =O)CC[C@]4(C)[C@H ┆                   ┆ CC(=O)CC[C@]4(C) │
# │                   ┆                   ┆ ]3CC[C@]12C)C(C)C ┆                   ┆ [C@H]3CC[C@]12C) │
# │                   ┆                   ┆                   ┆                   ┆ C(C)C            │
# │ C18cdc9c82847bcf1 ┆ IGZHRGYGJFOCHE-JZ ┆ COc1cc([C@H]2OC[C ┆ IGZHRGYGJFOCHE-JZ ┆ COc1cc([C@H]2OC[ │
# │ 87312e44294c82fff ┆ KJUIAGSA-N        ┆ @H]3[C@@H]2CO[C@@ ┆ KJUIAGSA-N        ┆ C@H]3[C@@H]2CO[C │
# │ 5f72469           ┆                   ┆ H]3c2ccc3c(c2)OCO ┆                   ┆ @@H]3c2ccc3c(c2) │
# │                   ┆                   ┆ 3)ccc1OCCC=C(C)C  ┆                   ┆ OCO3)ccc1OCCC=C( │
# │                   ┆                   ┆                   ┆                   ┆ C)C              │
# │ C8b9ce3585db83d28 ┆ MFFDNJQADQPGPW-XS ┆ C=C1C(=O)O[C@@H]2 ┆ MFFDNJQADQPGPW-XS ┆ C=C1C(=O)O[C@@H] │
# │ 2c5202deacdb9f201 ┆ VYMCFTSA-N        ┆ [C@@H]1[C@@H](OC( ┆ VYMCFTSA-N        ┆ 2[C@@H]1[C@@H](O │
# │ 258cf44           ┆                   ┆ =O)C(C)C)[C@@H](O ┆                   ┆ C(=O)C(C)C)[C@@H │
# │                   ┆                   ┆ C(C)=O)[C@@](C)(O ┆                   ┆ ](OC(C)=O)[C@@]( │
# │                   ┆                   ┆ )[C@H]1C=C[C@](C) ┆                   ┆ C)(O)[C@H]1C=C[C │
# │                   ┆                   ┆ (OO)[C@H]21       ┆                   ┆ @](C)(OO)[C@H]21 │
# │ C2db990e085c899a3 ┆ ZVEYAIMRDBXWPO-DD ┆ C[C@H]1CC[C@H]2[C ┆ ZVEYAIMRDBXWPO-DD ┆ C[C@H]1CC[C@H]2[ │
# │ 065aa5edfb9fef7e4 ┆ TYTHBRSA-N        ┆ @@H](C=C[C@@H]3CO ┆ TYTHBRSA-N        ┆ C@@H](C=C[C@@H]3 │
# │ 89e6899           ┆                   ┆ [C@](C)(O)C(=O)[C ┆                   ┆ CO[C@](C)(O)C(=O │
# │                   ┆                   ┆ @@]32C)[C@@H]1O   ┆                   ┆ )[C@@]32C)[C@@H] │
# │                   ┆                   ┆                   ┆                   ┆ 1O               │
# │ Ccfeb8bd0a39d8d4b ┆ CUGDOWNTXKLQMD-UH ┆ COc1cc(O)c(C(=O)C ┆ CUGDOWNTXKLQMD-UH ┆ COc1cc(O)c(C(=O) │
# │ 3ed49319ccec24db3 ┆ FFFAOYSA-N        ┆ =Cc2ccccc2)c(O)c1 ┆ FFFAOYSA-N        ┆ C=Cc2ccccc2)c(O) │
# │ 18f07c0           ┆                   ┆                   ┆                   ┆ c1               │
# │ Cfb892aa215992d1a ┆ QVWPBWPQLTYKFZ-CP ┆ COc1cc(/C=C\C(=O) ┆ QVWPBWPQLTYKFZ-CP ┆ COc1cc(/C=C\C(=O │
# │                   ┆                   ┆ )C(=O)N[C@@H](C(C ┆                   ┆ ](C(C)O)C(=O)N[C │
# │                   ┆                   ┆ )C)C(=O)N(C)[C@@H ┆                   ┆ @@H](C(C)C)C(=O) │
# │                   ┆                   ┆ ](C(C)O)C(=O)N[C@ ┆                   ┆ N(C)[C@@H](C(C)O │
# │                   ┆                   ┆ @H](C(C)C)C(=O)N( ┆                   ┆ )C(=O)N[C@@H](C( │
# │                   ┆                   ┆ C)[C@H](C)C(=O)NC ┆                   ┆ C)C)C(=O)N(C)[C@ │
# │                   ┆                   ┆ C(=O)N[C@@H](C(C) ┆                   ┆ H](C)C(=O)NCC(=O │
# │                   ┆                   ┆ C)C(=O)N(C)[C@@H] ┆                   ┆ )N[C@@H](C(C)C)C │
# │                   ┆                   ┆ (CO)C(=O)N1C      ┆                   ┆ (=O)N(C)[C@@H](C │
# │                   ┆                   ┆                   ┆                   ┆ O)C(=O)N1C       │
# │ C7317872d4b46b454 ┆ VQBNWAFCSYEHLX-YY ┆ O=C(O)C1(O)C[C@@H ┆ VQBNWAFCSYEHLX-YY ┆ O=C(O)C1(O)C[C@@ │
# │ 57ffe0b642ddc8dfa ┆ OAKPANSA-N        ┆ ](O)C(O)[C@@](O)( ┆ OAKPANSA-N        ┆ H](O)C(O)[C@@](O │
# │ f6a85d9           ┆                   ┆ C(=O)c2cc(O)c(O)c ┆                   ┆ )(C(=O)c2cc(O)c( │
# │                   ┆                   ┆ (O)c2)C1(C(=O)c1c ┆                   ┆ O)c(O)c2)C1(C(=O │
# │                   ┆                   ┆ c(O)c(O)c(O)c1)C( ┆                   ┆ )c1cc(O)c(O)c(O) │
# │                   ┆                   ┆ =O)c1cc(O)c(O)c(O ┆                   ┆ c1)C(=O)c1cc(O)c │
# │                   ┆                   ┆ )c1               ┆                   ┆ (O)c(O)c1        │
# │ C4c2ab69af1103532 ┆ WUPLGASUDBCHAH-UH ┆ CC(C)=CCc1c(O)cc( ┆ WUPLGASUDBCHAH-UH ┆ CC(C)=CCc1c(O)cc │
# │ 38d94e293abb567f3 ┆ FFFAOYSA-N        ┆ O)c2c(=O)cc(C)oc1 ┆ FFFAOYSA-N        ┆ (O)c2c(=O)cc(C)o │
# │ 05c804c           ┆                   ┆ 2                 ┆                   ┆ c12              │
# │ Ce8307af7d1361de0 ┆ BIFZUAUNLQJSKA-GJ ┆ CC1=C(CO)C[C@]2(C ┆ BIFZUAUNLQJSKA-GJ ┆ CC1=C(CO)C[C@]2( │
# │ 0e0ba69f8aa31e5d4 ┆ ZGRUSLSA-N        ┆ )CCCC(C)(C)[C@]12 ┆ ZGRUSLSA-N        ┆ C)CCCC(C)(C)[C@] │
# │ abc8134           ┆                   ┆ C                 ┆                   ┆ 12C              │
# │ C37a1001d80486167 ┆ UBJRXOPIHHBJHV-UH ┆ COc1ccc2c(c1)=C1C ┆ UBJRXOPIHHBJHV-UH ┆ COc1ccc2c(c1)=C1 │
# │ 7a199a0cded4c3fcc ┆ FFFAOYSA-N        ┆ CN3C(=O)c4ccccc4N ┆ FFFAOYSA-N        ┆ CCN3C(=O)c4ccccc │
# │                   ┆                   ┆                   ┆                   ┆ 2                │
# │ C9f1ee27257e108d7 ┆ PFNFFQXMRSDOHW-UH ┆ NCCCNCCCCNCCCN    ┆ PFNFFQXMRSDOHW-UH ┆ NCCCNCCCCNCCCN   │
# │ 45882e94989903d78 ┆ FFFAOYSA-N        ┆                   ┆ FFFAOYSA-N        ┆                  │
# │ 4c436e1           ┆                   ┆                   ┆                   ┆                  │
# │ Ca44aac4fb1ae988b ┆ KCLMUIFNZXEZFL-SP ┆ C[C@@H](O)/C=C/[C ┆ KCLMUIFNZXEZFL-SP ┆ C[C@@H](O)/C=C/[ │
# │ fd40824b8a1736ebe ┆ YANFIISA-N        ┆ @@]1(O)[C@]2(C)CO ┆ YANFIISA-N        ┆ C@@]1(O)[C@]2(C) │
# │ e7db7bc           ┆                   ┆ [C@@]1(C)C[C@@H]( ┆                   ┆ CO[C@@]1(C)C[C@@ │
# │                   ┆                   ┆ O)C2              ┆                   ┆ H](O)C2          │
# │ C89051ec064362ee4 ┆ WUIYLXXBSXOSSJ-UH ┆ CCCC(=O)c1c(O)c2c ┆ WUIYLXXBSXOSSJ-UH ┆ CCCC(=O)c1c(O)c2 │
# │ 04e3046aeca3cd213 ┆ FFFAOYSA-N        ┆ (-c3ccccc3)cc(=O) ┆ FFFAOYSA-N        ┆ c(-c3ccccc3)cc(= │
# │ b908c4c           ┆                   ┆ oc2c2ccoc12       ┆                   ┆ O)oc2c2ccoc12    │
# │ Ced08cd462c9abd97 ┆ HXCWHJGIRYQQDZ-UH ┆ CC1=CCC2C(C)(C)CC ┆ HXCWHJGIRYQQDZ-UH ┆ CC1=CCC2C(C)(C)C │
# │ c91d5468201806ede ┆ FFFAOYSA-N        ┆ CC2(C)C1CC(OS(=O) ┆ FFFAOYSA-N        ┆ CCC2(C)C1CC(OS(= │
# │ 58a186f           ┆                   ┆ (=O)O)C(C)CCCc1cc ┆                   ┆ O)(=O)O)C(C)CCCc │
# │                   ┆                   ┆ oc1               ┆                   ┆ 1ccoc1           │
# │ Cfb5638c6d945fc3a ┆ SSWORBNMTDPEQY-UH ┆ CCCCCc1[nH]c2cccc ┆ SSWORBNMTDPEQY-UH ┆ CCCCCc1[nH]c2ccc │
# │ 3c8b01c4967d71825 ┆ FFFAOYSA-N        ┆ c2c(=O)c1C        ┆ FFFAOYSA-N        ┆ cc2c(=O)c1C      │
# │ 2fe5bb1           ┆                   ┆                   ┆                   ┆                  │
# │ C356c9a2080f7cf4c ┆ BOWWIAFHRQYJRF-PA ┆ O=C(OCc1cc(O)c(O[ ┆ BOWWIAFHRQYJRF-PA ┆ O=C(OCc1cc(O)c(O │
# │ c24af59879b9f8c51 ┆ QBHFIDSA-N        ┆ C@@H]2O[C@H](COC( ┆ QBHFIDSA-N        ┆ [C@@H]2O[C@H](CO │
# │ 6445294           ┆                   ┆ =O)c3cc(O)c(O)c(O ┆                   ┆ C(=O)c3cc(O)c(O) │
# │                   ┆                   ┆                   ┆                   ┆ [C@@H]13         │
# │ C6a28ffad2b17be2c ┆ INTUZWVQVCYQHS-UH ┆ CC(=O)OCC12C(OC(C ┆ INTUZWVQVCYQHS-UH ┆ CC(=O)OCC12C(OC( │
# │ 31dc8f059b2f1a3ef ┆ FFFAOYSA-N        ┆ )=O)C(OC(C)=O)C3C ┆ FFFAOYSA-N        ┆ C)=O)C(OC(C)=O)C │
# │ 431ff78           ┆                   ┆ (OC(=O)c4ccoc4)C1 ┆                   ┆ 3C(OC(=O)c4ccoc4 │
# │                   ┆                   ┆ 4OC3(C)COC(=O)c1c ┆                   ┆ )C14OC3(C)COC(=O │
# │                   ┆                   ┆ ccnc1C(C)C(C)C(=O ┆                   ┆ )c1cccnc1C(C)C(C │
# │                   ┆                   ┆ )OC(C(OC(=O)c1ccc ┆                   ┆ )C(=O)OC(C(OC(=O │
# │                   ┆                   ┆ cc1)C2OC(C)=O)C4( ┆                   ┆ )c1ccccc1)C2OC(C │
# │                   ┆                   ┆ C)O               ┆                   ┆ )=O)C4(C)O       │
# └───────────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %%
# %%time

def check_smiles_in_pubchem(smiles):
    # URL encode the SMILES string
    smiles_encoded = urllib.parse.quote(smiles)
    
    # Use the PubChem API to convert SMILES to a CID (PubChem Compound ID)
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles_encoded}/cids/JSON"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if 'IdentifierList' in data and 'CID' in data['IdentifierList']:
            cids = data['IdentifierList']['CID']
            if cids:
                cid = cids[0]
                #print(f"SMILES found in PubChem with CID: {cid}")
                return cid
            else:
                print("SMILES not found in PubChem.")
                return None
        else:
            print("Unexpected response format.")
            return None
    else:
        #print(f"Error in accessing PubChem API. Status code: {response.status_code}")
        return None

def get_organisms_for_cid(cid):
    # Use the PubChem API to retrieve organisms associated with the CID
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON/?heading=Taxonomy"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        organisms = []
        if 'Record' in data and 'Section' in data['Record']:
            for section in data['Record']['Section']:
                if section.get("TOCHeading") == "Taxonomy":
                    for subsection in section.get("Section", []):
                        if subsection.get("TOCHeading") == "Organisms":
                            for info in subsection.get("Information", []):
                                organisms.append(info.get("Name", "Unknown organism"))
        return organisms
    else:
        #print(f"Error in retrieving organism data. Status code: {response.status_code}")
        return []


# compare SMILES_mongo or smiles_lotus
smiles_list = df_starting["SMILES_mongo"].unique().to_list()
print(len(smiles_list))
smiles_list = smiles_list[0:10]
cid_list = list()

# Iterate over the DataFrame rows and update CID
for smiles in smiles_list:
    cid = check_smiles_in_pubchem(smiles)

    if cid == None:
        cid_list.append(None)
    else:
        cid_list.append(cid)

    #print(f"Processed SMILES: {smiles}\n---")

# Print the updated DataFrame
print(f'cid_list [{len(cid_list)}], smiles_list [{len(smiles_list)}]')

# Create a new DataFrame with SMILES and CID
df_smiles_cid = pl.DataFrame({
    "SMILES_mongo": smiles_list,
    "CID": cid_list
})

print(df_smiles_cid)
df_joined = df_starting.join(df_smiles_cid, on="SMILES_mongo", how="left")
# Out:
# 147861
# cid_list [10], smiles_list [10]
# shape: (10, 2)
# ┌──────────────────────────────────────────────────────────────────────────────────────┬───────────┐
# │ SMILES_mongo                                                                         ┆ CID       │
# │ ---                                                                                  ┆ ---       │
# │ str                                                                                  ┆ i64       │
# ╞══════════════════════════════════════════════════════════════════════════════════════╪═══════════╡
# │ C=C1CC[C@H]2[C@](C)(CO)[C@H](O)CC[C@@]2(C)[C@@H]1CCC1=CCOC1=O                        ┆ 15922991  │
# │ CC(C)=CCC[C@@]1(C)Oc2c(O)cc3c(c2C[C@H]1O)O[C@H]1c2ccc(O)cc2OC[C@@H]31                ┆ 162852634 │
# │ CC(C)[C@H]1CC[C@@H](C)[C@]2(O)CCC(C(=O)O)=C[C@H]12                                   ┆ 145721093 │
# │ O=C(O)/C=C\c1ccc(O[C@@H]2O[C@H](COC(=O)c3cc(O)c(O)c(O)c3)[C@@H](O)[C@H](O)[C@H]2O)cc ┆ null      │
# │ 1                                                                                    ┆           │
# │ COc1cc(C)c(O)c(C/C=C(\C)CC(=O)/C=C(\C)CCC[C@H](C)[C@@H](O)C(=O)C=C(C)C)c1            ┆ null      │
# │ C=C[C@H](O)C/C(=N/OS(=O)(=O)O)S[C@H]1O[C@@H](CO)[C@H](O)[C@@H](O)[C@@H]1O            ┆ null      │
# │ COc1ccc(C=CC(=O)c2ccc(OC3OC(COC(C)=O)C(O)C(O)C3O)c(O)c2O)cc1O                        ┆ 85447318  │
# │ O=C(O)c1cc(O)nc2ccccc12                                                              ┆ 85076     │
# │ CCCCCCCC1CC(=O)NC(CO)C(=O)NC(CC(C)C)C(=O)OC(CCCCC)CC(=O)NC(CC(C)C)C(=O)NC(CO)C(=O)O1 ┆ 73237634  │
# │ CC1(COC(=O)c2cc(Br)c[nH]2)NC=NC(C(=O)O)C1O                                           ┆ 14846951  │
# └──────────────────────────────────────────────────────────────────────────────────────┴───────────┘
# CPU times: user 171 ms, sys: 64.7 ms, total: 236 ms
# Wall time: 6.26 s

# %% [markdown]
# ## *.parquet file

# %%
def check_smiles_in_pubchem(smiles):
    # URL encode the SMILES string
    smiles_encoded = urllib.parse.quote(smiles)

    # Use the PubChem API to convert SMILES to a CID (PubChem Compound ID)
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles_encoded}/cids/JSON"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if 'IdentifierList' in data and 'CID' in data['IdentifierList']:
            cids = data['IdentifierList']['CID']
            if cids:
                cid = cids[0]
                #print(f"SMILES found in PubChem with CID: {cid}")
                return cid
            else:
                print("SMILES not found in PubChem.")
                return None
        else:
            print("Unexpected response format.")
            return None
    else:
        #print(f"Error in accessing PubChem API. Status code: {response.status_code}")
        return None

def get_organisms_for_cid(cid):
    # Use the PubChem API to retrieve organisms associated with the CID
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON/?heading=Taxonomy"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        organisms = []
        if 'Record' in data and 'Section' in data['Record']:
            for section in data['Record']['Section']:
                if section.get("TOCHeading") == "Taxonomy":
                    for subsection in section.get("Section", []):
                        if subsection.get("TOCHeading") == "Organisms":
                            for info in subsection.get("Information", []):
                                organisms.append(info.get("Name", "Unknown organism"))
        return organisms
    else:
        #print(f"Error in retrieving organism data. Status code: {response.status_code}")
        return []

"""
>>>>>>> c7e1eb7 (update all)
# connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['compounds']

result = client['lotus_mines_enzymatic']['compounds'].find()

documents_list = list(result)

df_mongo = pl.DataFrame(documents_list)
df_mongo = df_mongo.drop(["Generation", "Expand", "Reactant_in", "Product_of", "Type"])
df_mongo = df_mongo.rename({"_id":"_id_mongo", 
                            "ID":"ID_mongo", 
                            "SMILES":"SMILES_mongo", 
                            "InChI_key":"InChI_key_mongo"})
"""



df_mongo = pl.read_parquet("../data/MINES/mongo_predicted_compounds.parquet")

# compare SMILES_mongo or smiles_lotus
smiles_list = df_mongo["SMILES_mongo"].unique().to_list()
cid_list = list()

print(f'df shape: {df_mongo.shape}  | SMILES list: {len(smiles_list)}')


# Iterate over the DataFrame rows and update CID
for smiles in smiles_list:
    cid = check_smiles_in_pubchem(smiles)

    if cid == None:
        cid_list.append(None)
    else:
        cid_list.append(cid)

# Print the updated DataFrame
print(f'cid_list [{len(cid_list)}], smiles_list [{len(smiles_list)}]')

# Create a new DataFrame with SMILES and CID
df_smiles_cid = pl.DataFrame({
    "SMILES_mongo": smiles_list,
    "CID": cid_list
})


df_joined = df_starting.join(df_smiles_cid, on="SMILES_mongo", how="left")
df_joined.write_parquet("../data/MINES/pubchem_all_compounds.parquet")
# Out:
# df shape: (3284418, 4)  | SMILES list: 3284418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 89
#      87 # Iterate over the DataFrame rows and update CID
#      88 for smiles in smiles_list:
# ---> 89     cid = check_smiles_in_pubchem(smiles)
#      91     if cid == None:
#      92         cid_list.append(None)
#
# Cell In[2], line 17, in check_smiles_in_pubchem(smiles)
#      15 # Use the PubChem API to convert SMILES to a CID (PubChem Compound ID)
#      16 url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles_encoded}/cids/JSON"
# ---> 17 response = requests.get(url)
#      19 if response.status_code == 200:
#      20     data = response.json()
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pubchempy as pcp
import csv, os

df_mongo = pl.read_parquet("../data/MINES/mongo_predicted_compounds.parquet")
file = "../data/taxonomy/smiles_cid.tsv"
smiles = df_mongo["SMILES_mongo"].unique().to_list()

smiles = smiles[0:50]


# Header to add
header = ['smile', 'cid_compound']

# Check if the file exists
if not os.path.exists(file):
    # File does not exist, create it and add the header
    with open(file, 'w', newline='') as file:
        writer = csv.writer(file, delimiter='\t')
        writer.writerow(header)
else:
    print(f"The file '{file}' already exists.")
    

for smile in smiles:
    c = pcp.get_compounds(smile, 'smiles')

    for compound in c:
        cid_compound = compound.cid
                    
        print(cid_compound)
        
        if cid_compound == None:
            print("nothing found")
        else:
            additional_data = [
                [smile, cid_compound],
            ]
            
            # Write data to a TSV file
            with open(filename, 'a', newline='') as file:
                writer = csv.writer(file, delimiter='\t')
                writer.writerows(additional_data)
# Out:
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# 538246
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# None
# nothing found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/pubchempy.py:271, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     270 log.debug('Request data: %s', postdata)
# --> 271 response = urlopen(apiurl, postdata)
#     272 return response
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File /usr/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: PUGREST.BadRequest
#
# During handling of the above exception, another exception occurred:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[64], line 25
#      21     print(f"The file '{file}' already exists.")
#      24 for smile in smiles:
# ---> 25     c = pcp.get_compounds(smile, 'smiles')
#      27     for compound in c:
#      28         cid_compound = compound.cid
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/pubchempy.py:321, in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     312 def get_compounds(identifier, namespace='cid', searchtype=None, as_dataframe=False, **kwargs):
#     313     """Retrieve the specified compound records from PubChem.
#     314
#     315     :param identifier: The compound identifier to use as a search query.
#    (...)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/pubchempy.py:299, in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297 """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298 try:
# --> 299     return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300 except NotFoundError as e:
#     301     log.info(e)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/pubchempy.py:292, in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290             response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291 else:
# --> 292     response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293 return response
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/pubchempy.py:274, in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     272     return response
#     273 except HTTPError as e:
# --> 274     raise PubChemHTTPError(e)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/pubchempy.py:1297, in PubChemHTTPError.__init__(self, e)
#    1295     pass
#    1296 if self.code == 400:
# -> 1297     raise BadRequestError(self.msg)
#    1298 elif self.code == 404:
#    1299     raise NotFoundError(self.msg)
#
# BadRequestError: 'PUGREST.BadRequest: error: '

# %%
import pubchempy as pcp

# Replace 'Aspirin' with the name of your compound
c = pcp.get_compounds('Aspirin', 'name', as_dataframe=False)

for co in c:
    print(co.cid)


c[0].cid, dir(c[0]), repr(c[0]), type(c)
# Out:
# 2244
# (2244,
#  ['__class__',
#   '__delattr__',
#   '__dict__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__le__',
#   '__lt__',
#   '__module__',
#   '__ne__',
#   '__new__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__setattr__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   '__weakref__',
#   '_atoms',
#   '_bonds',
#   '_record',
#   '_setup_atoms',
#   '_setup_bonds',
#   'aids',
#   'atom_stereo_count',
#   'atoms',
#   'bond_stereo_count',
#   'bonds',
#   'cactvs_fingerprint',
#   'canonical_smiles',
#   'charge',
#   'cid',
#   'complexity',
#   'conformer_id_3d',
#   'conformer_rmsd_3d',
#   'coordinate_type',
#   'covalent_unit_count',
#   'defined_atom_stereo_count',
#   'defined_bond_stereo_count',
#   'effective_rotor_count_3d',
#   'elements',
#   'exact_mass',
#   'feature_selfoverlap_3d',
#   'fingerprint',
#   'from_cid',
#   'h_bond_acceptor_count',
#   'h_bond_donor_count',
#   'heavy_atom_count',
#   'inchi',
#   'inchikey',
#   'isomeric_smiles',
#   'isotope_atom_count',
#   'iupac_name',
#   'mmff94_energy_3d',
#   'mmff94_partial_charges_3d',
#   'molecular_formula',
#   'molecular_weight',
#   'monoisotopic_mass',
#   'multipoles_3d',
#   'pharmacophore_features_3d',
#   'record',
#   'rotatable_bond_count',
#   'shape_fingerprint_3d',
#   'shape_selfoverlap_3d',
#   'sids',
#   'synonyms',
#   'to_dict',
#   'to_series',
#   'tpsa',
#   'undefined_atom_stereo_count',
#   'undefined_bond_stereo_count',
#   'volume_3d',
#   'xlogp'],
#  'Compound(2244)',
#  list)
