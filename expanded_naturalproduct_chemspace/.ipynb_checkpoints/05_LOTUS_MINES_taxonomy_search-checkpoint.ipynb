# %% [markdown]
# # Taxonomy search of predicted

# %%
import polars as pl
import defl as defl
from tqdm import tqdm

import matplotlib.pyplot as plt
import statistics
from pymongo import MongoClient
import os

# %% [markdown]
# ## comparing "Starting Compounds" with the Input file of MINEs

# %%
# load Inputfile
df_input_mines = pl.read_csv("../data/MINES/230106_frozen_metadata_inchy_smile.csv")

df_input_mines = df_input_mines.rename({"id":"InChI_key_lotus", "smiles":"smiles_lotus"})

df_input_mines

# %%
from pymongo import MongoClient

# connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['compounds']

# get all the Starting Compounds from the MongoDB
filter={
    'Type': 'Starting Compound'
}
result = client['lotus_mines_enzymatic']['compounds'].find(
  filter=filter
)

documents_list = list(result)

df_mongo = pl.DataFrame(documents_list)
df_mongo = df_mongo.drop(["Generation", "Expand", "Reactant_in", "Product_of", "Type"])
df_mongo = df_mongo.rename({"_id":"_id_mongo", 
                            "ID":"ID_mongo", 
                            "SMILES":"SMILES_mongo", 
                            "InChI_key":"InChI_key_mongo"})

df_mongo

# 147'885 told by MINES after removing stereochemistry (24 more than in the MongoDB found)

# %% [markdown]
# We can see a difference between the 147'885 compounds, which where accepted from MINEs
# to the 147'861 compounds which we got from our MongoDB.
# This are 24 less then originaly.
#
# This can be for example, because this 24 are not unique (what I dont expect) or that they didn't made a reaction. What is possible, but why don't store them...

# %%
# first check, if in the df_mongo the ID_mongo is the same as in the InChI_key_mongo
df_comparison_INCHY = df_mongo.with_columns(
    pl.col("ID_mongo").is_in(df_mongo["InChI_key_mongo"]).alias("ID_mongo_vs_InChI_key"),
)

df_comparison_INCHY = df_comparison_INCHY.filter(pl.col("ID_mongo_vs_InChI_key") == False)

df_comparison_INCHY

# %% [markdown]
# Whe we check the mongoDB for the ID (Inputfile Inchykey) and their own Inchykey, we could see some differences.
# From the 147'861 Input InchyKeys, 7'858 compounds (5.32 %) shown a different pattern.
#
# It is very likely, that this happen because of the removing of the stereochemistry.
#
#
# ### Understanding InChI Keys:
# The International Chemical Identifier (InChI) is a textual identifier for chemical substances, developed by the IUPAC. An InChI key is a fixed-length (27 characters) hashed version of the full InChI string, designed to be an easier way to reference the chemical structure in databases or literature.
#
# #### Structure of InChI Key:
# An InChI key is composed of three blocks:
#
# - First Block (14 characters): Encodes the connectivity information (skeletal structure).
# - Second Block (8 characters): Encodes stereochemistry information and isotopic information.
#      - examples of the two end characters in the second block:
#             **SA**: The most common, representing the standard stereochemistry and protonation state.
#             **NA**: No stereochemistry or isotopic information.
#             **AA**: Indicates that no stereochemical and isotopic information is provided, but the protonation state is standard.
# - Third Block (1 character): Encodes the version of the InChI algorithm used and the type of the InChIKey (standard[**N**] or non-standard [**O**]). Different protonation state, isotopic variation, or tautomerism are represented with an **O**.
#
# #### Meaning of the second block "UHFFFAOYSA"?
# In summary, **UHFFFAOYSA** is a common pattern in InChIKeys that corresponds to specific stereochemical information and protonation state. It often appears when no specific stereochemistry or isotopic information is present, or when the default protonation state is used.
# **UHFFFAOYNA** is normaly used to encode no stereochemistry and no protantation.

# %%
# get only the columns, where we interested
df_mongo_inchi = df_mongo.select(pl.col(["ID_mongo", "InChI_key_mongo"]))

# Step 1: Find all rows where `ID_mongo` and `InChI_key_mongo` are not similar.
non_similar_df = df_mongo_inchi.filter(pl.col("ID_mongo") != pl.col("InChI_key_mongo"))

# Step 2: From these non-similar rows, find those where only the last character differs.
# This is done by comparing everything except the last character and then checking if the last character is the only difference.

# Slice the strings to compare up to the second-to-last character
non_similar_but_almost_df = non_similar_df.filter(
    pl.col("ID_mongo").str.slice(0, 24) == pl.col("InChI_key_mongo").str.slice(0, 24)
)

# Finally, if you also want to ensure that only the last character is different:
last_char_diff_df = non_similar_but_almost_df.filter(
    pl.col("ID_mongo").str.slice(-1) != pl.col("InChI_key_mongo").str.slice(-1)
)

# Display the resulting DataFrame
last_char_diff_df

#last_char_diff_df.filter(pl.col("ID_mongo").str.slice(-1) == "O")

## check for flattened InchIkeys
#flattened_Inchy = non_similar_df.filter(
#    pl.col("ID_mongo").str.slice(0, 26) != pl.col("InChI_key_mongo").str.slice(0, 26)
#)

#flattened_Inchy_found = flattened_Inchy.filter(
#    pl.col("InChI_key_mongo").str.slice(14, 12) == "-UHFFFAOYSA-"
#)

#flattened_Inchy

# %% [markdown]
# #### Why only the last Character/Block changes?
# In the code above we can see, that we don't find any InchIKey with an **O** at the end.
# This means, that all the Input IDs of the MINEs file has a **N** in the end, what stand for standard.
#
# But when it runs through pickaxe, you will get some **O** in the end, which means non-standard.
#
# This is a little bit iritating, because this 265 compounds are technicaly the same.
#
#
# ##### What It Means:
# -N (Standard InChIKey): Represents the most common or default form of the molecule, usually the most stable tautomeric form, the most common protonation state at physiological pH, and without specific isotopic detail.
# -O (Non-standard InChIKey): Suggests that some non-standard detail is being considered—this could be a tautomeric form, a different protonation state, or an isotopic variant.

# %%
inchi_key_ID = "LMYYUVAVNWPEPG-GXAHKNHCSA-N"
inchi_key_MongoID = "LMYYUVAVNWPEPG-GXAHKNHCSA-O"

entry_mongodb = df_mongo.filter(pl.col("ID_mongo")== inchi_key)
entry_mines_inputfile = df_input_mines.filter(pl.col("InChI_key_lotus")== inchi_key_ID)

print(f'''
Source \t\tinchi key \t\t\t\tSMILES
MINES Input\t{inchi_key_ID}\t\t{entry_mongodb["SMILES_mongo"][0]}
MongoDB\t\t{inchi_key_MongoID}\t\t{entry_mines_inputfile["smiles_lotus"][0]}
''')

# %%
# compare the fields SMILES and ID (Inchykey) from the MongoDB and Inputfiel

# Check if df_mongo["ID_mongo"] exists in df_input_mines["InChI_key_lotus"]
df_comparison_SMILES = df_mongo.with_columns(
    pl.col("SMILES_mongo").is_in(df_input_mines["smiles_lotus"]).alias("comparison"),
)

df_comparison_SMILES = df_comparison_SMILES.filter(pl.col("comparison") == False)

df_comparison_SMILES

# %%
# Check if df_mongo["ID_mongo"] exists in df_input_mines["InChI_key_lotus"]
df_comparison = df_comparison_INCHY.with_columns(
    pl.col("ID_mongo").is_in(df_comparison_SMILES["ID_mongo"]).alias("SMILESvsINCHY"),
)

df_comparison = df_comparison.filter(pl.col("SMILESvsINCHY") == False)

df_comparison

# %%
df_comparison_INCHY = df_mongo.with_columns(
    pl.col("ID_mongo").is_in(df_mongo["InChI_key_mongo"]).alias("ID_mongo_vs_InChI_key"),
)

df_comparison_INCHY = df_comparison_INCHY.filter(pl.col("ID_mongo_vs_InChI_key") == True)


df_comparison_equal_INCHI = df_comparison_INCHY.with_columns(
    pl.col("SMILES_mongo").is_in(df_input_mines["smiles_lotus"]).alias("comparison"),
)

df_comparison_equal_INCHI_different_SMILES = df_comparison_equal_INCHI.filter(pl.col("comparison") == False)

df_comparison_equal_INCHI_different_SMILES

# %% [markdown]
# ## Predicted compound search

# %% [markdown]
# Given a known compound (SMILES) from LOTUS, we like to see the predicted compounds.

# %%
df = pl.read_parquet("../data/MINES/reactions_compounds_type_reactant_list.parquet")
print(f'length of original dataframe: {df.shape[0]:_}')

ID_INPUT = "Ccb4bbce54cc03da8afe0090e2869252ff6cb7aa8"
df_result = defl.find_predicted_compounds(df, ID_INPUT)

print(f'ID for *Starting compound* is {ID_INPUT}')
df_result

# %% [markdown]
# Find the median and standard deviation of all the starting compounds.

# %%
# %%time
"""
# This code was run in the script (starting_to_predicted.py) and 
# saved in /data/starting2predicted.parquet

# Here is only provided a samplecode with the first 100 entries.

df_starting_compounds = df.filter(pl.col("type") == "Starting Compound")
df_starting_compounds = df_starting_compounds.select(pl.col("id")).unique()

predicted_elements = list()

print(f"We found {len(df_starting_compounds):_} unique 'Starting Compounds'")

for starting_compound in tqdm(df_starting_compounds.head(100).iter_rows(), desc="Processing Starting Compounds"):
    df_predicted = defl.find_predicted_compounds(df, starting_compound[0])

    amount_of_predicted_compounds = df_predicted.shape[0]

    predicted_elements.append(amount_of_predicted_compounds)

    # Print detailed progress
    print(f"{starting_compound[0]} found {amount_of_predicted_compounds} compounds")

"""

# %%
predicted_elements = pl.read_parquet("../data/starting2predicted.parquet")
predicted_elements.rename({"predicted_compound_names":"starting_compound_id"})

predicted_elements_list = predicted_elements["predicted_elements"].to_list()

max(predicted_elements_list), min(predicted_elements_list)

# %% [markdown]
# ### visualize all the result from above

# %%
predicted_elements = predicted_elements_list

# Calculate average (mean) and standard deviation (SD)
average = statistics.mean(predicted_elements)
sd = statistics.stdev(predicted_elements)

print(f'average is {average:.2f} and standart deviation is {sd:.2f}.')

# Create histogram
plt.hist(predicted_elements, bins=1000, edgecolor='black', alpha=0.7)

# Add mean and SD lines
plt.axvline(average, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {average:.2f}')
plt.axvline(average + sd, color='blue', linestyle='dashed', linewidth=1, label=f'+1 SD: {average + sd:.2f}')
plt.axvline(average - sd, color='blue', linestyle='dashed', linewidth=1)

# Add title and labels
plt.title('Histogram')
plt.xlabel('amount of predicted compounds per input compound')
plt.ylabel('Frequency')
plt.legend()

# Set x-axis range
plt.xlim(0, 500)

# Show plot
plt.show()

# %%
df = pl.read_parquet("../data/MINES/reactions_compounds_list.parquet")

# Filter out rows with empty lists
df_filtered = df.filter((pl.col("starting_compounds").list.len() > 0) & (pl.col("predicted_compounds").list.len() > 0))

# Ensure both columns have matching element counts
df = df_filtered.explode(['starting_compounds']).explode(['predicted_compounds'])

predicted_elements_list = df["starting_compounds"].unique().to_list()


# Define the fields to retrieve
taxonomy_fields = [
    "organism_taxonomy_01domain",
    "organism_taxonomy_02kingdom",
    "organism_taxonomy_03phylum",
    "organism_taxonomy_04class",
    "organism_taxonomy_05order",
    "organism_taxonomy_06family",
    "organism_taxonomy_07tribe",
    "organism_taxonomy_08genus",
    "organism_taxonomy_09species",
    "organism_taxonomy_10varietas"
]


# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')  # Replace with your MongoDB connection string

# Select the database
db = client['lotus_mines_enzymatic']

# Select the collection
collection = db['lotus']


for taxom in taxonomy_fields:
    result_list = list()
    
    for starting_compound_id in predicted_elements_list:
        # Query to find the document by _id and retrieve only the taxonomy fields
        result = collection.find_one(
            {"_id": starting_compound_id}, 
            {
                taxom: 1,
                "_id": 1
            }
        )
    
        result_list.append(result)
        
        
    df_taxonomy = pl.DataFrame(result_list)
    
    
    df_joined = df.join(df_taxonomy, left_on="starting_compounds", right_on="_id", how="left")
    df_joined.write_parquet("../data/taxom_"+taxom+".parquet")

    print(f"done with {taxom}")
# Out:
# done with organism_taxonomy_01domain
# done with organism_taxonomy_02kingdom
# done with organism_taxonomy_03phylum
# done with organism_taxonomy_04class
# done with organism_taxonomy_05order
# done with organism_taxonomy_06family
# done with organism_taxonomy_07tribe
# done with organism_taxonomy_08genus
# done with organism_taxonomy_09species
# done with organism_taxonomy_10varietas

# %%
df_new = pl.read_parquet("../data/taxonomy/taxom_organism_taxonomy_02kingdom.parquet")
df_new
# Out:
# shape: (3_455_876, 4)
# ┌────────────────────────┬────────────────────────┬────────────────────────┬───────────────────────┐
# │ reaction_id            ┆ starting_compounds     ┆ predicted_compounds    ┆ organism_taxonomy_02k │
# │ ---                    ┆ ---                    ┆ ---                    ┆ ingdom                │
# │ str                    ┆ str                    ┆ str                    ┆ ---                   │
# │                        ┆                        ┆                        ┆ str                   │
# ╞════════════════════════╪════════════════════════╪════════════════════════╪═══════════════════════╡
# │ R5d8539f1d9a5e85718995 ┆ Ce8bc5cd3aa30776ab6d35 ┆ C878f017efe6de2805a953 ┆ Archaeplastida        │
# │ 6bad8eb48e7b11137a25b1 ┆ fdc2bcc4707f4ac2919    ┆ d0ca9b8491274a29290    ┆                       │
# │ 2c2a7293fa1b61562e629  ┆                        ┆                        ┆                       │
# │ R6a89aaf90529aa474f537 ┆ Ce8bc5cd3aa30776ab6d35 ┆ C54130f1c76aaa5380fa63 ┆ Archaeplastida        │
# │ c081d71ff584fa0179bdde ┆ fdc2bcc4707f4ac2919    ┆ 1a6a659121284978c5d    ┆                       │
# │ 8269c9ae4b80b2e5c96f7  ┆                        ┆                        ┆                       │
# │ Rf0c39549766c89963dbb1 ┆ Ce8bc5cd3aa30776ab6d35 ┆ Cfa5e885b86c8c37a465ca ┆ Archaeplastida        │
# │ a98f8f1d4b89431cf4ee60 ┆ fdc2bcc4707f4ac2919    ┆ d5238ed62672498a45d    ┆                       │
# │ f962c7703ef9df5bcb327  ┆                        ┆                        ┆                       │
# │ Rad931d485dae8cbc9aa07 ┆ Ce8bc5cd3aa30776ab6d35 ┆ C57a73b796ef9de341670a ┆ Archaeplastida        │
# │ Rc723ce445a5fba620734c ┆ C9e207ca3de0a74a8b2c0d ┆ C482f27d0b29b0db769b25 ┆ Archaeplastida        │
# │ cd14de894ed8c6a26015f5 ┆ f254e4df1cab725c370    ┆ f0125ead925f146b642    ┆                       │
# │ 86f8e93632852581f824c  ┆                        ┆                        ┆                       │
# │ Rb8ddccb3d03c58c136ea2 ┆ Ca9555f122d3c1dbb9dcc3 ┆ C70c44600418e9ee2471c9 ┆ Metazoa               │
# │ 91ba8e8611e131e900b799 ┆ 30c98bae9a5defb8524    ┆ 052a4f48ce8d34edea9    ┆                       │
# │ 1c869cdd61b7dc6031fa7  ┆                        ┆                        ┆                       │
# │ Rc52c2d326695e43c104ec ┆ C92af25813ba38f4e1f385 ┆ C5e8022bf3b0f1ee82b5ec ┆ Archaeplastida        │
# │ d4a11b20ead83987b49c39 ┆ dc92b0e253dc7a01f6c    ┆ 45f5c89f69ea2ab5a29    ┆                       │
# │ bbc0c165c7d25b8fef8b5  ┆                        ┆                        ┆                       │
# │ Rb993c3707a42c88a14333 ┆ C326b3a90bc4bff0d2cf24 ┆ Ca4ef9345ff26e4fec21cc ┆ Archaeplastida        │
# │ 4e22d4af7eacf0dde11657 ┆ 9e40ce517af77a62d0d    ┆ 7fb72fa9dca2f86fcc5    ┆                       │
# │ 106b272262f033e17d424  ┆                        ┆                        ┆                       │
# │ Rc1fdf76ef8f34b7c3a753 ┆ C62f5460835a65fcb75c6c ┆ Ce9a6758cc6c58ca618292 ┆ Archaeplastida        │
# │ 8fcb9924dd3a44615fd990 ┆ 8da0f7f6f90c060d900    ┆ cde869df568a1c34cb8    ┆                       │
# │ b2da338cc61b791734e6d  ┆                        ┆                        ┆                       │
# └────────────────────────┴────────────────────────┴────────────────────────┴───────────────────────┘

# %%
def plot_frequency(df: pl.DataFrame, column_name: str, fill_null: str = "no taxonomy"):
    
    df = df.with_columns(df[last_column].fill_null("no taxonomy"))

    frequency_df = (
        df
        .group_by(column_name)
        .agg(pl.count().alias("count"))
        .sort("count", descending=True)
        .with_columns(
            (pl.col("count") / df.shape[0]).alias("relative_frequency")
        )
        .head(10)  # Keep only the top 10
    )

    # Step 2: Extract the data for plotting
    labels = frequency_df[column_name].to_list()
    relative_frequencies = frequency_df["relative_frequency"].to_list()

    uniqu_labels = frequency_df[column_name].unique().shape[0]

    # Step 3: Plot the relative frequency using matplotlib
    plt.figure(figsize=(10, 6))
    bars = plt.bar(labels, relative_frequencies, color='skyblue')
    plt.xlabel(column_name.capitalize())
    plt.ylabel('Relative Frequency')
    plt.title(f'Top 10 Relative Frequencies in {column_name.capitalize()} (Total: {uniqu_labels})')
    plt.xticks(rotation=90)

    for bar, freq in zip(bars, relative_frequencies):
        yval = bar.get_height()
        plt.text(
            bar.get_x() + bar.get_width() / 2, 
            yval, 
            f'{freq:.2%}', 
            ha='center', 
            va='bottom'
        )
           
    plt.show()

# %%
# Specify the folder where your parquet files are located
folder_path = '../data/taxonomy/'

# Iterate over each parquet file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.parquet'):
        file_path = os.path.join(folder_path, file_name)
        
        # Load the parquet file into a DataFrame using polars
        df = pl.read_parquet(file_path)
        
        # Identify the last column (since the name can be different)
        last_column = df.columns[-1]
        
        # First subplot: Group by starting_compounds
        df_grouped_starting = (
            df.group_by('starting_compounds', maintain_order=True)
            .agg([
                pl.col(last_column).unique()  # Aggregate and keep only unique values
            ])
        )
        df_grouped_starting = df_grouped_starting.explode(last_column)
        
        # Second subplot: Group by predicted_compounds
        df_grouped_predicted = df.select(pl.col(["predicted_compounds", last_column]))

        plot_frequency(df_grouped_starting, last_column)
        plot_frequency(df_grouped_predicted, last_column)

        
        print(f"starting df: {df_grouped_starting.head()} | {df_grouped_starting.shape[0]:_}")
        print(f"predicted df: {df_grouped_predicted.head()} | {df_grouped_predicted.shape[0]:_}")
# Out:
# /tmp/ipykernel_2313734/166550622.py:8: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
#   .agg(pl.count().alias("count"))
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬─────────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_09species │
# │ ---                                       ┆ ---                         │
# │ str                                       ┆ str                         │
# ╞═══════════════════════════════════════════╪═════════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Filago congesta             │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Parinari sprucei            │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Calotropis gigantea         │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Penicillium chrysogenum     │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Delphinium majus            │
# └───────────────────────────────────────────┴─────────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬─────────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_09species │
# │ ---                                       ┆ ---                         │
# │ str                                       ┆ str                         │
# ╞═══════════════════════════════════════════╪═════════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Filago congesta             │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Filago congesta             │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Filago congesta             │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Filago congesta             │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Filago congesta             │
# └───────────────────────────────────────────┴─────────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_05order │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Asterales                 │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Malpighiales              │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Gentianales               │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Eurotiales                │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Ranunculales              │
# └───────────────────────────────────────────┴───────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_05order │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Asterales                 │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Asterales                 │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Asterales                 │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Asterales                 │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Asterales                 │
# └───────────────────────────────────────────┴───────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬──────────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_10varietas │
# │ ---                                       ┆ ---                          │
# │ str                                       ┆ str                          │
# ╞═══════════════════════════════════════════╪══════════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ null                         │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ null                         │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ null                         │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ null                         │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ null                         │
# └───────────────────────────────────────────┴──────────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬──────────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_10varietas │
# │ ---                                       ┆ ---                          │
# │ str                                       ┆ str                          │
# ╞═══════════════════════════════════════════╪══════════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ null                         │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ null                         │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ null                         │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ null                         │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ null                         │
# └───────────────────────────────────────────┴──────────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_04class │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Magnoliopsida             │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Magnoliopsida             │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Magnoliopsida             │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Eurotiomycetes            │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Magnoliopsida             │
# └───────────────────────────────────────────┴───────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_04class │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Magnoliopsida             │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Magnoliopsida             │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Magnoliopsida             │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Magnoliopsida             │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Magnoliopsida             │
# └───────────────────────────────────────────┴───────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬────────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_01domain │
# │ ---                                       ┆ ---                        │
# │ str                                       ┆ str                        │
# ╞═══════════════════════════════════════════╪════════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Eukaryota                  │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Eukaryota                  │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Eukaryota                  │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Eukaryota                  │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Eukaryota                  │
# └───────────────────────────────────────────┴────────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬────────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_01domain │
# │ ---                                       ┆ ---                        │
# │ str                                       ┆ str                        │
# ╞═══════════════════════════════════════════╪════════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Eukaryota                  │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Eukaryota                  │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Eukaryota                  │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Eukaryota                  │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Eukaryota                  │
# └───────────────────────────────────────────┴────────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬─────────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_02kingdom │
# │ ---                                       ┆ ---                         │
# │ str                                       ┆ str                         │
# ╞═══════════════════════════════════════════╪═════════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Archaeplastida              │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Archaeplastida              │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Archaeplastida              │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Fungi                       │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Archaeplastida              │
# └───────────────────────────────────────────┴─────────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬─────────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_02kingdom │
# │ ---                                       ┆ ---                         │
# │ str                                       ┆ str                         │
# ╞═══════════════════════════════════════════╪═════════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Archaeplastida              │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Archaeplastida              │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Archaeplastida              │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Archaeplastida              │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Archaeplastida              │
# └───────────────────────────────────────────┴─────────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_08genus │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Filago                    │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Parinari                  │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Calotropis                │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Penicillium               │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Delphinium                │
# └───────────────────────────────────────────┴───────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_08genus │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Filago                    │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Filago                    │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Filago                    │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Filago                    │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Filago                    │
# └───────────────────────────────────────────┴───────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬────────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_06family │
# │ ---                                       ┆ ---                        │
# │ str                                       ┆ str                        │
# ╞═══════════════════════════════════════════╪════════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Asteraceae                 │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Chrysobalanaceae           │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Apocynaceae                │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Trichocomaceae             │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Ranunculaceae              │
# └───────────────────────────────────────────┴────────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬────────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_06family │
# │ ---                                       ┆ ---                        │
# │ str                                       ┆ str                        │
# ╞═══════════════════════════════════════════╪════════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Asteraceae                 │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Asteraceae                 │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Asteraceae                 │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Asteraceae                 │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Asteraceae                 │
# └───────────────────────────────────────────┴────────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬────────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_03phylum │
# │ ---                                       ┆ ---                        │
# │ str                                       ┆ str                        │
# ╞═══════════════════════════════════════════╪════════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Streptophyta               │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ Streptophyta               │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Streptophyta               │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ Ascomycota                 │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Streptophyta               │
# └───────────────────────────────────────────┴────────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬────────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_03phylum │
# │ ---                                       ┆ ---                        │
# │ str                                       ┆ str                        │
# ╞═══════════════════════════════════════════╪════════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Streptophyta               │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Streptophyta               │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Streptophyta               │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Streptophyta               │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Streptophyta               │
# └───────────────────────────────────────────┴────────────────────────────┘ | 3_455_876
# starting df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ starting_compounds                        ┆ organism_taxonomy_07tribe │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ Ce8bc5cd3aa30776ab6d35fdc2bcc4707f4ac2919 ┆ Gnaphalieae               │
# │ Cf3ff883e2601ad5ff1487b92aae0bc640572b398 ┆ null                      │
# │ C627a485a72821aaa9713c12b7b8f6a68c7864b5b ┆ Asclepiadeae              │
# │ C98f13ab5d980f69f74b8ad76f1524ac28dd1065c ┆ null                      │
# │ Cc8b88fde5c24db5066d9a348e78de07b2279f74b ┆ Delphinieae               │
# └───────────────────────────────────────────┴───────────────────────────┘ | 146_841
# predicted df: shape: (5, 2)
# ┌───────────────────────────────────────────┬───────────────────────────┐
# │ predicted_compounds                       ┆ organism_taxonomy_07tribe │
# │ ---                                       ┆ ---                       │
# │ str                                       ┆ str                       │
# ╞═══════════════════════════════════════════╪═══════════════════════════╡
# │ C878f017efe6de2805a953d0ca9b8491274a29290 ┆ Gnaphalieae               │
# │ C54130f1c76aaa5380fa631a6a659121284978c5d ┆ Gnaphalieae               │
# │ Cfa5e885b86c8c37a465cad5238ed62672498a45d ┆ Gnaphalieae               │
# │ C57a73b796ef9de341670ad4f895779c4ce0d4623 ┆ Gnaphalieae               │
# │ C8e1b680b68eec30be34c6b4857d630e2c245759d ┆ Gnaphalieae               │
# └───────────────────────────────────────────┴───────────────────────────┘ | 3_455_876

# %%
# Assuming df_grouped_starting is your DataFrame and last_column is the name of the last column
# Add a column that stores the length of the lists in the last_column
df_with_lengths = df_grouped_starting.with_columns(
    list_length = pl.col(last_column).arr.n_unique()
)

# Filter rows where the list length is greater than one
filtered_df = df_with_lengths.filter(
    pl.col("list_length") > 1
)

# Drop the helper column if you only want the original columns
filtered_df = filtered_df.drop("list_length")

print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Assuming df_grouped_starting is your DataFrame and last_column is the name of the last column
#       2 # Add a column that stores the length of the lists in the last_column
# ----> 3 df_with_lengths = df_grouped_starting.with_columns(
#       4     list_length = pl.col(last_column).arr.n_unique()
#       5 )
#       7 # Filter rows where the list length is greater than one
#       8 filtered_df = df_with_lengths.filter(
#       9     pl.col("list_length") > 1
#      10 )
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/polars/dataframe/frame.py:8890, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    8744 def with_columns(
#    8745     self,
#    8746     *exprs: IntoExpr | Iterable[IntoExpr],
#    8747     **named_exprs: IntoExpr,
#    8748 ) -> DataFrame:
#    8749     """
#    8750     Add columns to this DataFrame.
#    8751
#    (...)
#    8888     └─────┴──────┴─────────────┘
#    8889     """
# -> 8890     return self.lazy().with_columns(*exprs, **named_exprs).collect(_eager=True)
#
# File ~/expanded-naturalproduct-chemspace/.venv/lib/python3.10/site-packages/polars/lazyframe/frame.py:2027, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2025 # Only for testing purposes
#    2026 callback = _kwargs.get("post_opt_callback", callback)
# -> 2027 return wrap_df(ldf.collect(callback))
#
# SchemaError: invalid series dtype: expected `FixedSizeList`, got `list[str]`

# %%
  # Plot the data
        fig, axs = plt.subplots(1, 2, figsize=(14, 7))
        fig.suptitle(f'Circle Diagrams for {file_name}', fontsize=16)
        
        # First subplot: starting_compounds vs last_column
        axs[0].pie(df_grouped_starting[last_column].apply(len), labels=df_grouped_starting['starting_compounds'], autopct='%1.1f%%')
        axs[0].set_title('Starting Compounds vs Last Column')
        
        # Second subplot: predicted_compounds vs last_column
        axs[1].pie(df_grouped_predicted[last_column].apply(len), labels=df_grouped_predicted['predicted_compounds'], autopct='%1.1f%%')
        axs[1].set_title('Predicted Compounds vs Last Column')
        
        # Show the plot
        plt.show()
