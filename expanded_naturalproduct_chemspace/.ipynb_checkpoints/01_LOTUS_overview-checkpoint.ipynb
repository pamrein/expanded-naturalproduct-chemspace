# %% [markdown]
# # LOTUS - dataset overview
#
# [LOTUS initiative](https://lotus.nprod.net/) is a database of natural products connected to organisms. Befor expanding the database, we like to have an overview about the last LOTUS datasest.
#
# [latest LOTUS dataset (v10)](https://zenodo.org/records/7534071)
#
# More info in the [Paper (DOI:70780)](https://elifesciences.org/articles/70780)
#
#
# ## load dataset

# %%
# Example of loading LOTUS datasets with polars (python module)
import polars as pl
import numpy as np
from defl import * 

# change the configsetting, to see the full tables
pl.Config.set_tbl_rows(100)
pl.Config(fmt_str_lengths=550)

df_lotus = load_lotus_csv("../data/LOTUS/230106_frozen_metadata.csv.gz")
print(f"all columns of LOTUS (total: {df_lotus.shape[1]}): \n{df_lotus.columns}")
# Out:
# all columns of LOTUS (total: 39):
# ['structure_wikidata', 'structure_inchikey', 'structure_inchi', 'structure_smiles', 'structure_molecular_formula', 'structure_exact_mass', 'structure_xlogp', 'structure_smiles_2D', 'structure_cid', 'structure_nameIupac', 'structure_nameTraditional', 'structure_stereocenters_total', 'structure_stereocenters_unspecified', 'structure_taxonomy_npclassifier_01pathway', 'structure_taxonomy_npclassifier_02superclass', 'structure_taxonomy_npclassifier_03class', 'structure_taxonomy_classyfire_chemontid', 'structure_taxonomy_classyfire_01kingdom', 'structure_taxonomy_classyfire_02superclass', 'structure_taxonomy_classyfire_03class', 'structure_taxonomy_classyfire_04directparent', 'organism_wikidata', 'organism_name', 'organism_taxonomy_gbifid', 'organism_taxonomy_ncbiid', 'organism_taxonomy_ottid', 'organism_taxonomy_01domain', 'organism_taxonomy_02kingdom', 'organism_taxonomy_03phylum', 'organism_taxonomy_04class', 'organism_taxonomy_05order', 'organism_taxonomy_06family', 'organism_taxonomy_07tribe', 'organism_taxonomy_08genus', 'organism_taxonomy_09species', 'organism_taxonomy_10varietas', 'reference_wikidata', 'reference_doi', 'manual_validation']
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.

# %%
# example of "cbg" entry

df = df_lotus.filter((pl.col("structure_nameTraditional") == "Limonene") & (pl.col("organism_taxonomy_09species") == "Cannabis sativa"))[0, :]

df.write_csv("Limonene.csv", separator=",")

# %% [markdown]
# The 39 columns are separated in **natural products (NP)**, **chemical structure**,  **organism** and the **source**.

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

for columnname in df_lotus.columns:
    # count the appearance of each "word" in the given column
    df_lotus_plot = df_lotus.select(pl.col(columnname).value_counts(sort=True, name="n")).unnest(columnname)

    # print the 5 most common names
    print(columnname, ":", df_lotus_plot[0:5, :])
# Out:
# structure_wikidata : shape: (5, 2)
# ┌─────────────────────────────────┬──────┐
# │ structure_wikidata              ┆ n    │
# │ ---                             ┆ ---  │
# │ str                             ┆ u32  │
# ╞═════════════════════════════════╪══════╡
# │ http://www.wikidata.org/entity… ┆ 4156 │
# │ http://www.wikidata.org/entity… ┆ 3142 │
# │ http://www.wikidata.org/entity… ┆ 3006 │
# │ http://www.wikidata.org/entity… ┆ 2390 │
# │ http://www.wikidata.org/entity… ┆ 2294 │
# └─────────────────────────────────┴──────┘
# structure_inchikey : shape: (5, 2)
# ┌─────────────────────────────┬──────┐
# │ structure_inchikey          ┆ n    │
# │ ---                         ┆ ---  │
# │ str                         ┆ u32  │
# ╞═════════════════════════════╪══════╡
# │ IPCSVZSSVZVIGE-UHFFFAOYSA-N ┆ 4156 │
# │ KZJWDPNRJALLNS-VJSFXXLFSA-N ┆ 3142 │
# │ HCXVJBMSMIARIN-PHZDYDNGSA-N ┆ 3006 │
# │ REFJWTPEDVJJIY-UHFFFAOYSA-N ┆ 2390 │
# │ XMGQYMWWDOXHJM-UHFFFAOYSA-N ┆ 2294 │
# └─────────────────────────────┴──────┘
# structure_inchi : shape: (5, 2)
# ┌─────────────────────────────────┬──────┐
# │ structure_inchi                 ┆ n    │
# │ ---                             ┆ ---  │
# │ str                             ┆ u32  │
# ╞═════════════════════════════════╪══════╡
# │ InChI=1S/C16H32O2/c1-2-3-4-5-6… ┆ 4156 │
# │ InChI=1S/C29H50O/c1-7-21(19(2)… ┆ 3142 │
# │ InChI=1S/C29H48O/c1-7-21(19(2)… ┆ 3006 │
# │ InChI=1S/C15H10O7/c16-7-4-10(1… ┆ 2390 │
# │ InChI=1S/C10H16/c1-8(2)10-6-4-… ┆ 2294 │
# └─────────────────────────────────┴──────┘
# structure_smiles : shape: (5, 2)
# ┌─────────────────────────────────┬──────┐
# │ structure_smiles                ┆ n    │
# │ ---                             ┆ ---  │
# │ str                             ┆ u32  │
# ╞═════════════════════════════════╪══════╡
# │ CCCCCCCCCCCCCCCC(=O)O           ┆ 4156 │
# │ CC[C@H](CC[C@@H](C)[C@H]1CC[C@… ┆ 3142 │
# │ CC[C@H](/C=C/[C@@H](C)[C@H]1CC… ┆ 3006 │
# │ O=c1c(O)c(-c2ccc(O)c(O)c2)oc2c… ┆ 2390 │
# │ C=C(C)C1CC=C(C)CC1              ┆ 2294 │
# └─────────────────────────────────┴──────┘
# structure_molecular_formula : shape: (5, 2)
# ┌─────────────────────────────┬───────┐
# │ structure_molecular_formula ┆ n     │
# │ ---                         ┆ ---   │
# │ str                         ┆ u32   │
# ╞═════════════════════════════╪═══════╡
# │ C15H24                      ┆ 16034 │
# │ C10H16                      ┆ 15255 │
# │ C10H18O                     ┆ 8916  │
# │ C30H50O                     ┆ 6910  │
# │ C29H48O                     ┆ 5975  │
# └─────────────────────────────┴───────┘
# structure_exact_mass : shape: (5, 2)
# ┌──────────────────────┬───────┐
# │ structure_exact_mass ┆ n     │
# │ ---                  ┆ ---   │
# │ f64                  ┆ u32   │
# ╞══════════════════════╪═══════╡
# │ 204.187801           ┆ 16034 │
# │ 136.125201           ┆ 15255 │
# │ 154.135765           ┆ 8916  │
# │ 222.198365           ┆ 5787  │
# │ 412.370516           ┆ 5110  │
# └──────────────────────┴───────┘
# structure_xlogp : shape: (5, 2)
# ┌─────────────────┬──────┐
# │ structure_xlogp ┆ n    │
# │ ---             ┆ ---  │
# │ f32             ┆ u32  │
# ╞═════════════════╪══════╡
# │ 8.0248          ┆ 8253 │
# │ 2.9987          ┆ 6618 │
# │ 4.7252          ┆ 5069 │
# │ 7.8008          ┆ 4764 │
# │ 3.3089          ┆ 4412 │
# └─────────────────┴──────┘
# structure_smiles_2D : shape: (5, 2)
# ┌─────────────────────────────────┬──────┐
# │ structure_smiles_2D             ┆ n    │
# │ ---                             ┆ ---  │
# │ str                             ┆ u32  │
# ╞═════════════════════════════════╪══════╡
# │ CCC(CCC(C)C1CCC2C3CC=C4CC(O)CC… ┆ 4986 │
# │ CCC(C=CC(C)C1CCC2C3CC=C4CC(O)C… ┆ 4406 │
# │ CCCCCCCCCCCCCCCC(=O)O           ┆ 4156 │
# │ O=c1c(OC2OC(CO)C(O)C(O)C2O)c(-… ┆ 3019 │
# │ C=C(C)C1CC=C(C)CC1              ┆ 2958 │
# └─────────────────────────────────┴──────┘
# structure_cid : shape: (5, 2)
# ┌───────────────┬───────┐
# │ structure_cid ┆ n     │
# │ ---           ┆ ---   │
# │ u32           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ null          ┆ 15889 │
# │ 222284        ┆ 3142  │
# │ 5280794       ┆ 3006  │
# │ 5280343       ┆ 2390  │
# │ 22311         ┆ 2294  │
# └───────────────┴───────┘
# structure_nameIupac : shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ structure_nameIupac             ┆ n     │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ null                            ┆ 18112 │
# │ (3S,8S,9S,10R,13R,14S,17R)-17-… ┆ 3142  │
# │ (3S,8S,9S,10R,13R,14S,17R)-17-… ┆ 3006  │
# │ 2-(3,4-dihydroxyphenyl)-3,5,7-… ┆ 2390  │
# │ 1-methyl-4-prop-1-en-2-ylcyclo… ┆ 2294  │
# └─────────────────────────────────┴───────┘
# structure_nameTraditional : shape: (5, 2)
# ┌───────────────────────────┬───────┐
# │ structure_nameTraditional ┆ n     │
# │ ---                       ┆ ---   │
# │ str                       ┆ u32   │
# ╞═══════════════════════════╪═══════╡
# │ null                      ┆ 15967 │
# │ Beta-Sitosterol           ┆ 3142  │
# │ Stigmasterol              ┆ 3006  │
# │ Quercetin                 ┆ 2390  │
# │ Limonene                  ┆ 2294  │
# └───────────────────────────┴───────┘
# structure_stereocenters_total : shape: (5, 2)
# ┌───────────────────────────────┬────────┐
# │ structure_stereocenters_total ┆ n      │
# │ ---                           ┆ ---    │
# │ u32                           ┆ u32    │
# ╞═══════════════════════════════╪════════╡
# │ 0                             ┆ 203327 │
# │ 1                             ┆ 94743  │
# │ 2                             ┆ 75061  │
# │ 5                             ┆ 68529  │
# │ 4                             ┆ 53048  │
# └───────────────────────────────┴────────┘
# structure_stereocenters_unspecified : shape: (5, 2)
# ┌─────────────────────────────────┬────────┐
# │ structure_stereocenters_unspec… ┆ n      │
# │ ---                             ┆ ---    │
# │ u32                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ 0                               ┆ 639159 │
# │ 1                               ┆ 57354  │
# │ 2                               ┆ 27833  │
# │ 5                               ┆ 10313  │
# │ 3                               ┆ 10252  │
# └─────────────────────────────────┴────────┘
# structure_taxonomy_npclassifier_01pathway : shape: (5, 2)
# ┌─────────────────────────────────┬────────┐
# │ structure_taxonomy_npclassifie… ┆ n      │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ Terpenoids                      ┆ 296899 │
# │ Shikimates and Phenylpropanoid… ┆ 206051 │
# │ Alkaloids                       ┆ 113284 │
# │ Polyketides                     ┆ 58093  │
# │ Fatty acids                     ┆ 48627  │
# └─────────────────────────────────┴────────┘
# structure_taxonomy_npclassifier_02superclass : shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ structure_taxonomy_npclassifie… ┆ n     │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ Flavonoids                      ┆ 78061 │
# │ Sesquiterpenoids                ┆ 67992 │
# │ Triterpenoids                   ┆ 56846 │
# │ Monoterpenoids                  ┆ 50250 │
# │ Diterpenoids                    ┆ 47237 │
# └─────────────────────────────────┴───────┘
# structure_taxonomy_npclassifier_03class : shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ structure_taxonomy_npclassifie… ┆ n     │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ null                            ┆ 55257 │
# │ Aminoacids                      ┆ 28298 │
# │ Flavonols                       ┆ 27228 │
# │ Flavones                        ┆ 21484 │
# │ Cinnamic acids and derivatives  ┆ 19405 │
# └─────────────────────────────────┴───────┘
# structure_taxonomy_classyfire_chemontid : shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ structure_taxonomy_classyfire_… ┆ n     │
# │ ---                             ┆ ---   │
# │ i64                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ 1553                            ┆ 33386 │
# │ 1550                            ┆ 27277 │
# │ 2031                            ┆ 14820 │
# │ 3531                            ┆ 13578 │
# │ 1551                            ┆ 13524 │
# └─────────────────────────────────┴───────┘
# structure_taxonomy_classyfire_01kingdom : shape: (3, 2)
# ┌─────────────────────────────────┬────────┐
# │ structure_taxonomy_classyfire_… ┆ n      │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ Organic compounds               ┆ 788301 │
# │ null                            ┆ 3483   │
# │ Inorganic compounds             ┆ 580    │
# └─────────────────────────────────┴────────┘
# structure_taxonomy_classyfire_02superclass : shape: (5, 2)
# ┌─────────────────────────────────┬────────┐
# │ structure_taxonomy_classyfire_… ┆ n      │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ Lipids and lipid-like molecule… ┆ 311399 │
# │ Phenylpropanoids and polyketid… ┆ 150068 │
# │ Organoheterocyclic compounds    ┆ 88532  │
# │ Organic acids and derivatives   ┆ 63878  │
# │ Benzenoids                      ┆ 51682  │
# └─────────────────────────────────┴────────┘
# structure_taxonomy_classyfire_03class : shape: (5, 2)
# ┌─────────────────────────────────┬────────┐
# │ structure_taxonomy_classyfire_… ┆ n      │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ Prenol lipids                   ┆ 215363 │
# │ Flavonoids                      ┆ 70587  │
# │ Steroids and steroid derivativ… ┆ 52957  │
# │ Carboxylic acids and derivativ… ┆ 50508  │
# │ Organooxygen compounds          ┆ 48052  │
# └─────────────────────────────────┴────────┘
# structure_taxonomy_classyfire_04directparent : shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ structure_taxonomy_classyfire_… ┆ n     │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ Triterpenoids                   ┆ 33386 │
# │ Sesquiterpenoids                ┆ 27277 │
# │ Stigmastanes and derivatives    ┆ 14820 │
# │ Flavonoid-3-O-glycosides        ┆ 13578 │
# │ Diterpenoids                    ┆ 13524 │
# └─────────────────────────────────┴───────┘
# organism_wikidata : shape: (5, 2)
# ┌─────────────────────────────────┬──────┐
# │ organism_wikidata               ┆ n    │
# │ ---                             ┆ ---  │
# │ str                             ┆ u32  │
# ╞═════════════════════════════════╪══════╡
# │ http://www.wikidata.org/entity… ┆ 6547 │
# │ http://www.wikidata.org/entity… ┆ 3310 │
# │ http://www.wikidata.org/entity… ┆ 3085 │
# │ http://www.wikidata.org/entity… ┆ 2242 │
# │ http://www.wikidata.org/entity… ┆ 1950 │
# └─────────────────────────────────┴──────┘
# organism_name : shape: (5, 2)
# ┌──────────────────────┬──────┐
# │ organism_name        ┆ n    │
# │ ---                  ┆ ---  │
# │ str                  ┆ u32  │
# ╞══════════════════════╪══════╡
# │ Streptomyces         ┆ 6547 │
# │ Homo sapiens         ┆ 3310 │
# │ Arabidopsis thaliana ┆ 3085 │
# │ Vitis vinifera       ┆ 2242 │
# │ Escherichia coli     ┆ 1950 │
# └──────────────────────┴──────┘
# organism_taxonomy_gbifid : shape: (5, 2)
# ┌──────────────────────────┬────────┐
# │ organism_taxonomy_gbifid ┆ n      │
# │ ---                      ┆ ---    │
# │ u32                      ┆ u32    │
# ╞══════════════════════════╪════════╡
# │ null                     ┆ 113794 │
# │ 2436436                  ┆ 3310   │
# │ 11103803                 ┆ 3085   │
# │ 5372392                  ┆ 2242   │
# │ 2930137                  ┆ 1674   │
# └──────────────────────────┴────────┘
# organism_taxonomy_ncbiid : shape: (5, 2)
# ┌──────────────────────────┬────────┐
# │ organism_taxonomy_ncbiid ┆ n      │
# │ ---                      ┆ ---    │
# │ u32                      ┆ u32    │
# ╞══════════════════════════╪════════╡
# │ null                     ┆ 124513 │
# │ 1883                     ┆ 6547   │
# │ 9606                     ┆ 3310   │
# │ 3702                     ┆ 3085   │
# │ 29760                    ┆ 2242   │
# └──────────────────────────┴────────┘
# organism_taxonomy_ottid : shape: (5, 2)
# ┌─────────────────────────┬───────┐
# │ organism_taxonomy_ottid ┆ n     │
# │ ---                     ┆ ---   │
# │ u32                     ┆ u32   │
# ╞═════════════════════════╪═══════╡
# │ null                    ┆ 11212 │
# │ 772892                  ┆ 6549  │
# │ 770315                  ┆ 3310  │
# │ 309263                  ┆ 3085  │
# │ 756728                  ┆ 2242  │
# └─────────────────────────┴───────┘
# organism_taxonomy_01domain : shape: (4, 2)
# ┌────────────────────────────┬────────┐
# │ organism_taxonomy_01domain ┆ n      │
# │ ---                        ┆ ---    │
# │ str                        ┆ u32    │
# ╞════════════════════════════╪════════╡
# │ Eukaryota                  ┆ 735225 │
# │ Bacteria                   ┆ 45809  │
# │ null                       ┆ 11212  │
# │ Archaea                    ┆ 118    │
# └────────────────────────────┴────────┘
# organism_taxonomy_02kingdom : shape: (4, 2)
# ┌─────────────────────────────┬────────┐
# │ organism_taxonomy_02kingdom ┆ n      │
# │ ---                         ┆ ---    │
# │ str                         ┆ u32    │
# ╞═════════════════════════════╪════════╡
# │ Archaeplastida              ┆ 624415 │
# │ null                        ┆ 65994  │
# │ Fungi                       ┆ 63243  │
# │ Metazoa                     ┆ 38712  │
# └─────────────────────────────┴────────┘
# organism_taxonomy_03phylum : shape: (5, 2)
# ┌────────────────────────────┬────────┐
# │ organism_taxonomy_03phylum ┆ n      │
# │ ---                        ┆ ---    │
# │ str                        ┆ u32    │
# ╞════════════════════════════╪════════╡
# │ Streptophyta               ┆ 617532 │
# │ Ascomycota                 ┆ 47707  │
# │ Actinobacteria             ┆ 27471  │
# │ null                       ┆ 18697  │
# │ Basidiomycota              ┆ 14804  │
# └────────────────────────────┴────────┘
# organism_taxonomy_04class : shape: (5, 2)
# ┌───────────────────────────┬────────┐
# │ organism_taxonomy_04class ┆ n      │
# │ ---                       ┆ ---    │
# │ str                       ┆ u32    │
# ╞═══════════════════════════╪════════╡
# │ Magnoliopsida             ┆ 582615 │
# │ null                      ┆ 71331  │
# │ Eurotiomycetes            ┆ 17757  │
# │ Sordariomycetes           ┆ 16345  │
# │ Agaricomycetes            ┆ 14364  │
# └───────────────────────────┴────────┘
# organism_taxonomy_05order : shape: (5, 2)
# ┌───────────────────────────┬───────┐
# │ organism_taxonomy_05order ┆ n     │
# │ ---                       ┆ ---   │
# │ str                       ┆ u32   │
# ╞═══════════════════════════╪═══════╡
# │ Asterales                 ┆ 79676 │
# │ Lamiales                  ┆ 62554 │
# │ Fabales                   ┆ 55257 │
# │ Sapindales                ┆ 40606 │
# │ Ranunculales              ┆ 34415 │
# └───────────────────────────┴───────┘
# organism_taxonomy_06family : shape: (5, 2)
# ┌────────────────────────────┬───────┐
# │ organism_taxonomy_06family ┆ n     │
# │ ---                        ┆ ---   │
# │ str                        ┆ u32   │
# ╞════════════════════════════╪═══════╡
# │ Asteraceae                 ┆ 78148 │
# │ Fabaceae                   ┆ 53926 │
# │ Lamiaceae                  ┆ 41123 │
# │ null                       ┆ 28395 │
# │ Rutaceae                   ┆ 24563 │
# └────────────────────────────┴───────┘
# organism_taxonomy_07tribe : shape: (5, 2)
# ┌───────────────────────────┬────────┐
# │ organism_taxonomy_07tribe ┆ n      │
# │ ---                       ┆ ---    │
# │ str                       ┆ u32    │
# ╞═══════════════════════════╪════════╡
# │ null                      ┆ 431362 │
# │ Mentheae                  ┆ 19306  │
# │ Anthemideae               ┆ 17957  │
# │ Delphinieae               ┆ 9000   │
# │ Heliantheae               ┆ 8455   │
# └───────────────────────────┴────────┘
# organism_taxonomy_08genus : shape: (5, 2)
# ┌───────────────────────────┬───────┐
# │ organism_taxonomy_08genus ┆ n     │
# │ ---                       ┆ ---   │
# │ str                       ┆ u32   │
# ╞═══════════════════════════╪═══════╡
# │ Streptomyces              ┆ 22833 │
# │ null                      ┆ 15523 │
# │ Salvia                    ┆ 8728  │
# │ Artemisia                 ┆ 8502  │
# │ Aspergillus               ┆ 8452  │
# └───────────────────────────┴───────┘
# organism_taxonomy_09species : shape: (5, 2)
# ┌─────────────────────────────┬───────┐
# │ organism_taxonomy_09species ┆ n     │
# │ ---                         ┆ ---   │
# │ str                         ┆ u32   │
# ╞═════════════════════════════╪═══════╡
# │ null                        ┆ 45020 │
# │ Homo sapiens                ┆ 3310  │
# │ Arabidopsis thaliana        ┆ 3085  │
# │ Vitis vinifera              ┆ 2242  │
# │ Escherichia coli            ┆ 1950  │
# └─────────────────────────────┴───────┘
# organism_taxonomy_10varietas : shape: (5, 2)
# ┌─────────────────────────────────┬────────┐
# │ organism_taxonomy_10varietas    ┆ n      │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ null                            ┆ 788336 │
# │ Pueraria montana var. lobata    ┆ 198    │
# │ Larix gmelinii var. gmelinii    ┆ 141    │
# │ Cynara cardunculus var. scolym… ┆ 130    │
# │ Citrus medica var. sarcodactyl… ┆ 109    │
# └─────────────────────────────────┴────────┘
# reference_wikidata : shape: (5, 2)
# ┌─────────────────────────────────┬──────┐
# │ reference_wikidata              ┆ n    │
# │ ---                             ┆ ---  │
# │ str                             ┆ u32  │
# ╞═════════════════════════════════╪══════╡
# │ http://www.wikidata.org/entity… ┆ 1786 │
# │ http://www.wikidata.org/entity… ┆ 1483 │
# │ http://www.wikidata.org/entity… ┆ 1330 │
# │ http://www.wikidata.org/entity… ┆ 1074 │
# │ http://www.wikidata.org/entity… ┆ 1000 │
# └─────────────────────────────────┴──────┘
# reference_doi : shape: (5, 2)
# ┌──────────────────────────────┬──────┐
# │ reference_doi                ┆ n    │
# │ ---                          ┆ ---  │
# │ str                          ┆ u32  │
# ╞══════════════════════════════╪══════╡
# │ 10.1016/0305-1978(86)90092-X ┆ 1786 │
# │ 10.1007/S11306-016-1051-4    ┆ 1483 │
# │ 10.1038/NBT.2488             ┆ 1330 │
# │ 10.1371/JOURNAL.PONE.0175573 ┆ 1074 │
# │ 10.2307/4117899              ┆ 1000 │
# └──────────────────────────────┴──────┘
# manual_validation : shape: (2, 2)
# ┌───────────────────┬────────┐
# │ manual_validation ┆ n      │
# │ ---               ┆ ---    │
# │ str               ┆ u32    │
# ╞═══════════════════╪════════╡
# │ null              ┆ 792154 │
# │ Y                 ┆ 210    │
# └───────────────────┴────────┘

# %% [markdown]
# For the pickaxe (MINEs) it is necessary to provide a SMILE and a ID.
# In this case would be used the coloumns **3D SMILES (structure_smiles)** and **structure_wikidata**.

# %%
# write in bold the specific title
print("\033[1m\nuniqueness over categories:\033[0m")

# unique counts only of the "chemical structure" columns
unique_counts = df_lotus.select(
    df_lotus.columns[0:20]
    ).n_unique()
print("all structure columns:", str(unique_counts))

# unique counts only of the "organism" columns []
unique_counts = df_lotus.select(
    df_lotus.columns[21:35]
    ).n_unique()
print("all organism columns:", str(unique_counts))

# unique counts for the full dataset
unique_counts = df_lotus.select(
    df_lotus.columns[:]
    ).n_unique()
print("all columns:", str(unique_counts))

# unique counts for the pickaxe/MINEs input
print("\033[1m\nImportant Info for pickaxe (MINEs):\033[0m")
print(f'rows for LOTUS dataset: {df_lotus.shape[0]}')
print(f'\nunique "structure_smiles": {df_lotus.select(["structure_smiles"]).n_unique()}')
print(f'unique "structure_wikidata": {df_lotus.select(["structure_wikidata"]).n_unique()}')
print(f'unique "structure_smiles" and "structure_wikidata": {df_lotus.select(["structure_smiles", "structure_wikidata"]).n_unique()}')
print(f'\nunique "structure_smiles": {df_lotus.select(["structure_smiles"]).n_unique()}')
print(f'unique "structure_inchi": {df_lotus.select(["structure_inchi"]).n_unique()}')
print(f'unique "structure_smiles" and "structure_inchi": {df_lotus.select(["structure_smiles", "structure_inchi"]).n_unique()}')
# Out:
# uniqueness over categories:
# all structure columns: 257226
# all organism columns: 36803
# all columns: 792364
#
# Important Info for pickaxe (MINEs):
# rows for LOTUS dataset: 792364
#
# unique "structure_smiles": 220820
# unique "structure_wikidata": 220783
# unique "structure_smiles" and "structure_wikidata": 220834
#
# unique "structure_smiles": 220820
# unique "structure_inchi": 220823
# unique "structure_smiles" and "structure_inchi": 220823

# %% [markdown]
# The uniqueness will be reduced from the full dataset (792'364 rows) to the pickaxe inputfile "structure_smiles" and "structure_wikidata" (220'834 rows), which is **27.9%** of the full dataset.
#
# This are good news, so the dataset will be reduced drasticaly.
#
# Which is a little unusual that we have more SMILES than wikidata links.
# This could be, because not all SMILES have a wikidata link yet, which in turn cannot be because LOTUS is ‘complete’ and has no empty fields.
#
# If we look at the inchi's, it is also a little bit surprising, that there should be 3 duplicates.

# %%
# make a dataframe with only the two columns: "structure_smiles" and "structure_wikidata"
df_lotus_for_pickaxe_with_wikidata = df_lotus.select(["structure_smiles", "structure_wikidata"]).unique()

# search for the duplicates and print them
df_lotus_for_pickaxe_with_wikidata_duplicates = df_lotus_for_pickaxe_with_wikidata.filter(df_lotus_for_pickaxe_with_wikidata.select(['structure_smiles']).is_duplicated()).sort('structure_smiles')
print(f'{df_lotus_for_pickaxe_with_wikidata_duplicates[0:2, :]}')


# make a dataframe with only the two columns: "structure_smiles" and "structure_inchi"
df_lotus_for_pickaxe_with_inchi = df_lotus.select(["structure_smiles", "structure_inchi"]).unique()

# search for the duplicates and print them
df_lotus_for_pickaxe_with_inchi_duplicates = df_lotus_for_pickaxe_with_inchi.filter(df_lotus_for_pickaxe_with_inchi.select(['structure_smiles']).is_duplicated()).sort('structure_smiles')
print(f'{df_lotus_for_pickaxe_with_inchi_duplicates[0:2, :]}')
# Out:
# shape: (2, 2)
# ┌───────────────────┬──────────────────────────────────────────┐
# │ structure_smiles  ┆ structure_wikidata                       │
# │ ---               ┆ ---                                      │
# │ str               ┆ str                                      │
# ╞═══════════════════╪══════════════════════════════════════════╡
# │ C1CCC2(CCCCO2)OC1 ┆ http://www.wikidata.org/entity/Q55620521 │
# │ C1CCC2(CCCCO2)OC1 ┆ http://www.wikidata.org/entity/Q804105   │
# └───────────────────┴──────────────────────────────────────────┘
# shape: (2, 2)
# ┌─────────────────────────────────────────────────┬────────────────────────────────────────────────┐
# │ structure_smiles                                ┆ structure_inchi                                │
# │ ---                                             ┆ ---                                            │
# │ str                                             ┆ str                                            │
# ╞═════════════════════════════════════════════════╪════════════════════════════════════════════════╡
# │ CC1=C\C=C\C(C)=C\C[C@H](C)NC(=O)/C(CC(C)C)=C/C( ┆ InChI=1S/C46H71N3O8/c1-30(2)26-36-27-33(5)19-1 │
# │ C)=C/C=C/C=C/[C@@](C)(O)[C@@H](O[C@@H]2OC[C@@H] ┆ 3-12-16-25-45(8,52)38(22-15-14-18-31(3)20-17-2 │
# │ (O[C@H]3C[C@@](C)(O)[C@H](N(C)C)[C@@H](C)O3)[C@ ┆ 1-32(4)23-24-34(6)48-43(36)51)57-44-40(47)41(5 │
# │ H](O)[C@H]2N)/C=C\C=C\1                         ┆ 0)37(29-54-44)56-39-28-46(9,53)42(49(10)11)35( │
# │                                                 ┆ 7)55-39/h12-23,25,27,30,34-35,37-42,44,50,52-5 │
# │                                                 ┆ 3H,24,26,28-29,47H2,1-11H3,(H,48,51)/b13-12+,1 │
# │                                                 ┆ 8-14+,21-17+,22-15+,25-16+,31-20+,32-23+,33-19 │
# │                                                 ┆ +,36-27+/t34-,35+,37+,38-,39-,40+,41-,42+,44-, │
# │                                                 ┆ 45+,46+/m0/s1                                  │
# │ CC1=C\C=C\C(C)=C\C[C@H](C)NC(=O)/C(CC(C)C)=C/C( ┆ InChI=1S/C46H71N3O8/c1-30(2)26-36-27-33(5)19-1 │
# │ C)=C/C=C/C=C/[C@@](C)(O)[C@@H](O[C@@H]2OC[C@@H] ┆ 3-12-16-25-45(8,52)38(22-15-14-18-31(3)20-17-2 │
# │ (O[C@H]3C[C@@](C)(O)[C@H](N(C)C)[C@@H](C)O3)[C@ ┆ 1-32(4)23-24-34(6)48-43(36)51)57-44-40(47)41(5 │
# │ H](O)[C@H]2N)/C=C\C=C\1                         ┆ 0)37(29-54-44)56-39-28-46(9,53)42(49(10)11)35( │
# │                                                 ┆ 7)55-39/h12-23,25,27,30,34-35,37-42,44,50,52-5 │
# │                                                 ┆ 3H,24,26,28-29,47H2,1-11H3,(H,48,51)/b13-12+,1 │
# │                                                 ┆ 8-14+,21-17+,22-15-,25-16+,31-20+,32-23+,33-19 │
# │                                                 ┆ +,36-27+/t34-,35+,37+,38-,39-,40+,41-,42+,44-, │
# │                                                 ┆ 45+,46+/m0/s1                                  │
# └─────────────────────────────────────────────────┴────────────────────────────────────────────────┘

# %% [markdown]
# The real reason is, that some SMILES have two wikidata entries, which is confusing. If we check the links, they are both linked to the "same" chemical component.
# This makes also sense, because the amount of this duplicated entries (28) correspond to the amount of entries of only SMILES (220820) plus the additinal entries (14).
#
# The same problem we can see with the INCHI's. In this case, we have multiple inchi's for the same SMILE's. This is possible, because the INCHI's describes the molecule more exactly then the SMILES.
#
# ## Why do we have less wikidata links then SMILES? This is a lose of information, no?
# We can see below, that some wikidatalinks are pointing to multiple SMILE's. This can be the case, because the wikilinks sometimes are represanting chemical groupes.

# %%
# make a dataframe with only the two columns: "structure_smiles" and "structure_wikidata"
df_lotus_for_pickaxe_with_wikidata = df_lotus.select(["structure_smiles", "structure_wikidata"]).unique()

# search for the duplicates and print them
df_lotus_for_pickaxe_with_wikidata_duplicates = df_lotus_for_pickaxe_with_wikidata.filter(df_lotus_for_pickaxe_with_wikidata.select(['structure_wikidata']).is_duplicated()).sort('structure_wikidata')
print(f'{df_lotus_for_pickaxe_with_wikidata_duplicates[0:2, :]}')
# Out:
# shape: (2, 2)
# ┌──────────────────────────────────────────────────────┬───────────────────────────────────────────┐
# │ structure_smiles                                     ┆ structure_wikidata                        │
# │ ---                                                  ┆ ---                                       │
# │ str                                                  ┆ str                                       │
# ╞══════════════════════════════════════════════════════╪═══════════════════════════════════════════╡
# │ C/C=C1/CN2CC[C@@]34c5ccccc5N5[C@H](C(=O)OC)[C@H]1C[C ┆ http://www.wikidata.org/entity/Q105144092 │
# │ @H]2[C@]53Oc1c4cc2c(c1O)C(=O)O[C@]13[C@@H]4C[C@H]5/C ┆                                           │
# │ (=C\C)CN4CC[C@@]21c1ccccc1N3[C@@H]5C(=O)OC           ┆                                           │
# │ C/C=C1/CN2CC[C@]34c5ccccc5N5[C@H](C(=O)OC)[C@H]1C[C@ ┆ http://www.wikidata.org/entity/Q105144092 │
# │ H]2[C@@]53Oc1c4cc2c(c1O)C(=O)O[C@@]13[C@@H]4C[C@H]5/ ┆                                           │
# │ C(=C\C)CN4CC[C@@]21c1ccccc1N3[C@@H]5C(=O)OC          ┆                                           │
# └──────────────────────────────────────────────────────┴───────────────────────────────────────────┘
