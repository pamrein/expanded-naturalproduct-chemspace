# %%
import matplotlib.pyplot as plt
import polars as pl
import numpy as np

from pymongo import MongoClient


def replace_id(df, replace_name = 'InChI_key'):
    # Load the DataFrame using Polars
    
    # Connect to MongoDB
    client = MongoClient('mongodb://localhost:27017/')
    db = client['lotus_mines']
    
    # Fetch the compounds collection
    compounds_collection = db['compounds']
    
    # Prepare a list to store the results
    results = []
    
    # Iterate over each row in the DataFrame
    for row in df.iter_rows(named=True):
        _id = row['id']
        
        # Find the corresponding compound using _id
        compound = compounds_collection.find_one({'_id': _id})
        
        if compound:
            replace_value = compound.get(replace_name)
            results.append({
                'id': _id,
                replace_name: replace_value
            })
            print(f"Found replace_name: {replace_value} for id: {_id}")
        else:
            print(f"No compound found for id: {_id}")
    
    # Convert the results to a DataFrame
    results_df = pl.DataFrame(results)

    results_df = df.with_columns(results_df[replace_name].alias("id"))
    
    # Display the results
    return results_df


df = pl.read_parquet("../data/statistic/reactions_compounds_list_full.csv")
df
# Out:
# shape: (3_435_078, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ reaction_id                    ┆ reactants                      ┆ products                       │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ list[struct[2]]                ┆ list[struct[2]]                │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ R5d8539f1d9a5e857189956bad8eb4 ┆ [{"Ce8bc5cd3aa30776ab6d35fdc2b ┆ [{"C878f017efe6de2805a953d0ca9 │
# │ …                              ┆ …                              ┆ …                              │
# │ R6a89aaf90529aa474f537c081d71f ┆ [{"Ce8bc5cd3aa30776ab6d35fdc2b ┆ [{"C54130f1c76aaa5380fa631a6a6 │
# │ …                              ┆ …                              ┆ …                              │
# │ Rf0c39549766c89963dbb1a98f8f1d ┆ [{"Ce8bc5cd3aa30776ab6d35fdc2b ┆ [{"Cfa5e885b86c8c37a465cad5238 │
# │ …                              ┆ …                              ┆ …                              │
# │ Rad931d485dae8cbc9aa07c1301163 ┆ [{"Ce8bc5cd3aa30776ab6d35fdc2b ┆ [{"C57a73b796ef9de341670ad4f89 │
# │ …                              ┆ …                              ┆ …                              │
# │ R02b3ad62ed7e42f819c6931a7d392 ┆ [{"Ce8bc5cd3aa30776ab6d35fdc2b ┆ [{"C8e1b680b68eec30be34c6b4857 │
# │ …                              ┆ …                              ┆ …                              │
# │ …                              ┆ …                              ┆ …                              │
# │ Rc52c2d326695e43c104ecd4a11b20 ┆ [{"C92af25813ba38f4e1f385dc92b ┆ [{"C5e8022bf3b0f1ee82b5ec45f5c │
# │ …                              ┆ …                              ┆ …                              │
# │ Rb993c3707a42c88a143334e22d4af ┆ [{"C326b3a90bc4bff0d2cf249e40c ┆ [{"Ca4ef9345ff26e4fec21cc7fb72 │
# │ …                              ┆ …                              ┆ …                              │
# │ Rc1fdf76ef8f34b7c3a7538fcb9924 ┆ [{"C62f5460835a65fcb75c6c8da0f ┆ [{"Ce9a6758cc6c58ca618292cde86 │
# │ …                              ┆ …                              ┆ …                              │
# │ Rbe1a7403def3e4c0a1dac139d28a0 ┆ [{"C2001018bdb89adc25ce61dd084 ┆ [{"C58fecaa1205bf8dee7e0704097 │
# │ …                              ┆ …                              ┆ …                              │
# │ R8bfd15f7bcb4f5f7bdd310a4b4132 ┆ [{"C40881f419ad2021ee247fd90e6 ┆ [{"C6e540dcff6053a94ee5729f652 │
# │ …                              ┆ …                              ┆ …                              │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘

# %%
# %%time

# Explode reactants and products
reactants_exploded = df.explode("reactants").select(pl.col(["reaction_id", "reactants"])).unnest("reactants").with_columns(pl.lit(True).alias('reactant'))
products_exploded = df.explode("products").select(pl.col(["reaction_id", "products"])).unnest("products").with_columns(pl.lit(False).alias('reactant'))

reactants_exploded, products_exploded
# Out:
# CPU times: user 8.54 s, sys: 8.3 s, total: 16.8 s
# Wall time: 16.6 s
# (shape: (7_648_891, 4)
#  ┌─────────────────────────────────┬─────────────────────────────────┬───────────────────┬──────────┐
#  │ reaction_id                     ┆ id                              ┆ type              ┆ reactant │
#  │ ---                             ┆ ---                             ┆ ---               ┆ ---      │
#  │ str                             ┆ str                             ┆ str               ┆ bool     │
#  ╞═════════════════════════════════╪═════════════════════════════════╪═══════════════════╪══════════╡
#  │ R5d8539f1d9a5e857189956bad8eb4… ┆ Ce8bc5cd3aa30776ab6d35fdc2bcc4… ┆ Starting Compound ┆ true     │
#  │ R5d8539f1d9a5e857189956bad8eb4… ┆ X0eb45233dd43ecacb9fb1e3114045… ┆ Coreactant        ┆ true     │
#  │ R5d8539f1d9a5e857189956bad8eb4… ┆ X8dc023d8052d83fb6feadf8541387… ┆ Coreactant        ┆ true     │
#  │ R6a89aaf90529aa474f537c081d71f… ┆ Ce8bc5cd3aa30776ab6d35fdc2bcc4… ┆ Starting Compound ┆ true     │
#  │ R6a89aaf90529aa474f537c081d71f… ┆ X0eb45233dd43ecacb9fb1e3114045… ┆ Coreactant        ┆ true     │
#  │ …                               ┆ …                               ┆ …                 ┆ …        │
#  │ Rc52c2d326695e43c104ecd4a11b20… ┆ C92af25813ba38f4e1f385dc92b0e2… ┆ Starting Compound ┆ true     │
#  │ Rb993c3707a42c88a143334e22d4af… ┆ C326b3a90bc4bff0d2cf249e40ce51… ┆ Starting Compound ┆ true     │
#  │ Rc1fdf76ef8f34b7c3a7538fcb9924… ┆ C62f5460835a65fcb75c6c8da0f7f6… ┆ Starting Compound ┆ true     │
#  │ Rbe1a7403def3e4c0a1dac139d28a0… ┆ C2001018bdb89adc25ce61dd084300… ┆ Starting Compound ┆ true     │
#  │ R8bfd15f7bcb4f5f7bdd310a4b4132… ┆ C40881f419ad2021ee247fd90e6c86… ┆ Starting Compound ┆ true     │
#  └─────────────────────────────────┴─────────────────────────────────┴───────────────────┴──────────┘,
#  shape: (7_111_280, 4)
#  ┌─────────────────────────────────┬─────────────────────────────────┬───────────────────┬──────────┐
#  │ reaction_id                     ┆ id                              ┆ type              ┆ reactant │
#  │ ---                             ┆ ---                             ┆ ---               ┆ ---      │
#  │ str                             ┆ str                             ┆ str               ┆ bool     │
#  ╞═════════════════════════════════╪═════════════════════════════════╪═══════════════════╪══════════╡
#  │ R5d8539f1d9a5e857189956bad8eb4… ┆ C878f017efe6de2805a953d0ca9b84… ┆ Predicted         ┆ false    │
#  │ R5d8539f1d9a5e857189956bad8eb4… ┆ X73bc8ef21db580aefe4dbc0af17d4… ┆ Coreactant        ┆ false    │
#  │ R6a89aaf90529aa474f537c081d71f… ┆ C54130f1c76aaa5380fa631a6a6591… ┆ Predicted         ┆ false    │
#  │ R6a89aaf90529aa474f537c081d71f… ┆ X73bc8ef21db580aefe4dbc0af17d4… ┆ Coreactant        ┆ false    │
#  │ Rf0c39549766c89963dbb1a98f8f1d… ┆ Cfa5e885b86c8c37a465cad5238ed6… ┆ Predicted         ┆ false    │
#  │ …                               ┆ …                               ┆ …                 ┆ …        │
#  │ Rc1fdf76ef8f34b7c3a7538fcb9924… ┆ X05622481c18728cacf9317e9a57ce… ┆ Coreactant        ┆ false    │
#  │ Rbe1a7403def3e4c0a1dac139d28a0… ┆ C58fecaa1205bf8dee7e07040978bc… ┆ Starting Compound ┆ false    │
#  │ Rbe1a7403def3e4c0a1dac139d28a0… ┆ X05622481c18728cacf9317e9a57ce… ┆ Coreactant        ┆ false    │
#  │ R8bfd15f7bcb4f5f7bdd310a4b4132… ┆ C6e540dcff6053a94ee5729f652c14… ┆ Starting Compound ┆ false    │
#  │ R8bfd15f7bcb4f5f7bdd310a4b4132… ┆ X05622481c18728cacf9317e9a57ce… ┆ Coreactant        ┆ false    │
#  └─────────────────────────────────┴─────────────────────────────────┴───────────────────┴──────────┘)

# %%
df_comp = pl.concat([reactants_exploded, products_exploded], how="vertical")  

print(df_comp)
# Out:
# shape: (14_760_171, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────────────────┬──────────┐
# │ reaction_id                     ┆ id                              ┆ type              ┆ reactant │
# │ ---                             ┆ ---                             ┆ ---               ┆ ---      │
# │ str                             ┆ str                             ┆ str               ┆ bool     │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════════════════╪══════════╡
# │ R5d8539f1d9a5e857189956bad8eb4… ┆ Ce8bc5cd3aa30776ab6d35fdc2bcc4… ┆ Starting Compound ┆ true     │
# │ R5d8539f1d9a5e857189956bad8eb4… ┆ X0eb45233dd43ecacb9fb1e3114045… ┆ Coreactant        ┆ true     │
# │ R5d8539f1d9a5e857189956bad8eb4… ┆ X8dc023d8052d83fb6feadf8541387… ┆ Coreactant        ┆ true     │
# │ R6a89aaf90529aa474f537c081d71f… ┆ Ce8bc5cd3aa30776ab6d35fdc2bcc4… ┆ Starting Compound ┆ true     │
# │ R6a89aaf90529aa474f537c081d71f… ┆ X0eb45233dd43ecacb9fb1e3114045… ┆ Coreactant        ┆ true     │
# │ …                               ┆ …                               ┆ …                 ┆ …        │
# │ Rc1fdf76ef8f34b7c3a7538fcb9924… ┆ X05622481c18728cacf9317e9a57ce… ┆ Coreactant        ┆ false    │
# │ Rbe1a7403def3e4c0a1dac139d28a0… ┆ C58fecaa1205bf8dee7e07040978bc… ┆ Starting Compound ┆ false    │
# │ Rbe1a7403def3e4c0a1dac139d28a0… ┆ X05622481c18728cacf9317e9a57ce… ┆ Coreactant        ┆ false    │
# │ R8bfd15f7bcb4f5f7bdd310a4b4132… ┆ C6e540dcff6053a94ee5729f652c14… ┆ Starting Compound ┆ false    │
# │ R8bfd15f7bcb4f5f7bdd310a4b4132… ┆ X05622481c18728cacf9317e9a57ce… ┆ Coreactant        ┆ false    │
# └─────────────────────────────────┴─────────────────────────────────┴───────────────────┴──────────┘

# %%
# Filter data by type
starting_compounds = df_comp.filter(pl.col('type') == 'Starting Compound')

# Count the occurrences of starting compounds for each starting compound ID
starting_count = starting_compounds.group_by('id').count()
starting_count = starting_count.sort('count', descending=True)

starting_count = replace_id(starting_count[0:20], replace_name="structure_nameTraditional" )

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(starting_count['id'], starting_count['count'], color='blue')
plt.xlabel('InChI_key of Starting Compound')
plt.ylabel('Amount of Predicted Compounds')
plt.title('Starting Compound')
plt.xticks(rotation=90)
plt.show()

print(starting_count)
# Out:
# /tmp/ipykernel_1801614/3376734721.py:5: DeprecationWarning: `count` is deprecated. It has been renamed to `len`.
#   starting_count = starting_compounds.group_by('id').count()
# Found replace_name: Alpha D-Galactose for id: C9ab1a08d72c90a8167d1f3a668d8f1138e534a07
# Found replace_name: Methanol for id: Cf32ec10ed591559703aa6d0857bdee249c4e1a4d
# Found replace_name: Acetone for id: Cf29ab8236bcc427a65d62b87ee3f7eb03d824537
# Found replace_name: Hydrochloric Acid for id: C33faa2b8ca452db82058619ed2de70883482f89d
# Found replace_name: Formic Acid for id: C0e2c8d649fd28524ed617a741b4da1c714899166
# Found replace_name: Methane for id: C3f8881998951e22f122db498b619af1eea58d2c1
# Found replace_name: L-Rhamnose for id: C2b9dd22b6408975452f0865c4ee28ca5254a1adb
# Found replace_name: beta-D-Arabinopyranose for id: Ca2c5b2bda608fea82809b23867a03096c9d0715c
# Found replace_name: Angelic acid for id: C41d99a021c3e0437fb983fa328d642276b2d0f1b
# Found replace_name: Benzoic Acid for id: Ce78e822bd39b86bbad3c1f7a4a256c00702cac00
# Found replace_name: Carbamic acid for id: C1cff1e0363c01af7dfb5a374f635aecd4ce8e77f
# Found replace_name: Gallic Acid for id: Cdea41c4f53a0dc0f39b4a9df5cd7b157514ed7c8
# Found replace_name: Isobutyric acid for id: C2d94449d2035580e3a2de661386c29c111c7bf71
# Found replace_name: 4-Hydroxybenzaldehyde for id: C575ccdba1fe8d09d15f369b7a87c1c8f6e4b3209
# Found replace_name: Glyoxylic acid for id: C14280ab89646dab5a4a6ec45a6ff2415e1eeea5b
# Found replace_name: 6-Methyl-5-hepten-2-one for id: C0b0897fb9532c0f4cc67c8706dc867c438f0921b
# Found replace_name: Benzaldehyde for id: C11795f842a1a740eb51f54c7920be4e5d1a09ca0
# Found replace_name: (S)-2-methylbutanoic acid for id: Cf30f602c179c10791dd924abb7522ea6a08a3e38
# Found replace_name: Glycolaldehyde for id: C236e0210dd1e0ace79113ebbaa280da49141926b
# Found replace_name: 2-Propenoic acid, 3-(4-hydroxyphenyl)-, (2Z)- for id: Ca922ecd8af032560a2a2662c4d4a862bee2bb766
# shape: (20, 2)
# ┌─────────────────────────────────┬───────┐
# │ id                              ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ Alpha D-Galactose               ┆ 15547 │
# │ Methanol                        ┆ 14947 │
# │ Acetone                         ┆ 11233 │
# │ Hydrochloric Acid               ┆ 9855  │
# │ Formic Acid                     ┆ 6328  │
# │ …                               ┆ …     │
# │ 6-Methyl-5-hepten-2-one         ┆ 1655  │
# │ Benzaldehyde                    ┆ 1634  │
# │ (S)-2-methylbutanoic acid       ┆ 1543  │
# │ Glycolaldehyde                  ┆ 1380  │
# │ 2-Propenoic acid, 3-(4-hydroxy… ┆ 1311  │
# └─────────────────────────────────┴───────┘

# %%
predicted_compounds = df_comp.filter(pl.col('type') == 'Predicted')

# Count the occurrences of predicted compounds for each starting compound ID
predicted_count = predicted_compounds.group_by('id').count()
predicted_count = predicted_count.sort('count', descending=True)

predicted_count = replace_id(predicted_count[0:20], replace_name="structure_nameTraditional")

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(predicted_count['id'], predicted_count['count'], color='blue')
plt.xlabel('InChI_key of Predicted Compounds')
plt.ylabel('Amount of Predicted Compounds')
plt.title('Predicted Compounds')
plt.xticks(rotation=90)
plt.show()


print(predicted_count)
# Out:
# /tmp/ipykernel_1801614/2757213455.py:4: DeprecationWarning: `count` is deprecated. It has been renamed to `len`.
#   predicted_count = predicted_compounds.group_by('id').count()
# Found replace_name: None for id: Cf832df7e99cab85f81bb00bc985412d7cf424409
# Found replace_name: None for id: Cbeafbb8f579e289f50a66a2be4f2bfc232c02d6f
# Found replace_name: None for id: C8ae480eb6c254b8a90818fcaffb6c7d6c8b74139
# Found replace_name: None for id: Ca3a0ad590f8aeb7045f5e92cf9f1d84377f98d15
# Found replace_name: None for id: C84cb2f7e765ed6494b6650a2615fc08606587f8a
# Found replace_name: None for id: Cbb4e00526d0f100dd7a79df741588c6836094166
# Found replace_name: None for id: C9ff2db8c112a1f93552bf1d2deef8310b8ca96b9
# Found replace_name: None for id: C226f0027de99ad0af9ba3423b1faacc62117cab0
# Found replace_name: None for id: Cf76eabd9f5b274e726753ccdff946386006aff0c
# Found replace_name: None for id: Cbe7d8c1f20311b2e2093befdee25a421c4c961e1
# Found replace_name: None for id: C65ee428fd4dd70b3764b1e3c36c414bd147b4678
# Found replace_name: None for id: C7b093cddb07cb8a3b08fc032f7477b5c219ce36a
# Found replace_name: None for id: C9c40bdedbfc6fece74b3fe6166400d5b634a00a8
# Found replace_name: None for id: C302f6003408a4ae601ca2a00f2e4b97f2437742a
# Found replace_name: None for id: C41f32ba8b32380c66a6ebb586a78f9840d758230
# Found replace_name: None for id: Cf8d5d72967eb632da3cf906a1986cb29ade1aedf
# Found replace_name: None for id: C651622b6345c7a4a7291ef7112d940775f1e1c1d
# Found replace_name: None for id: C6ba927363900cf2321815c91c9389eaa485c1951
# Found replace_name: None for id: C84081b6ab02a9da08e5082e92965013eee25f6e7
# Found replace_name: None for id: Cffe59099566ed52d086b9952fcc21b6e3a4d2931
# shape: (20, 2)
# ┌──────┬───────┐
# │ id   ┆ count │
# │ ---  ┆ ---   │
# │ null ┆ u32   │
# ╞══════╪═══════╡
# │ null ┆ 6928  │
# │ null ┆ 1206  │
# │ null ┆ 636   │
# │ null ┆ 515   │
# │ null ┆ 454   │
# │ …    ┆ …     │
# │ null ┆ 221   │
# │ null ┆ 212   │
# │ null ┆ 198   │
# │ null ┆ 194   │
# │ null ┆ 181   │
# └──────┴───────┘

# %%
df = df_comp

# Grouping and aggregating
result = (
    df.group_by("reaction_id")
    .agg([
        pl.when(pl.col("type") == "Coreactant").then(pl.col("id")).otherwise(None).alias("coreactant"),
        pl.when(pl.col("type") == "Starting Compound").then(pl.col("id")).otherwise(None).alias("starting_compound"),
        pl.when(pl.col("type") == "Predicted").then(pl.col("id")).otherwise(None).alias("predicted")
    ])
)

# Function to remove null values from a list
def remove_nulls(lst):
    return [x for x in lst if x is not None]

# Apply the function to each list column with specified return_dtype
df_cleaned = result.with_columns([
    pl.col("coreactant").apply(remove_nulls, return_dtype=pl.List(pl.Utf8)).alias("coreactant"),
    pl.col("starting_compound").apply(remove_nulls, return_dtype=pl.List(pl.Utf8)).alias("starting_compound"),
    pl.col("predicted").apply(remove_nulls, return_dtype=pl.List(pl.Utf8)).alias("predicted")
])

print(df_cleaned)

# Display the result
print(result)
# Out:
# /tmp/ipykernel_1801614/1137062065.py:19: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   pl.col("coreactant").apply(remove_nulls, return_dtype=pl.List(pl.Utf8)).alias("coreactant"),
# /tmp/ipykernel_1801614/1137062065.py:20: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   pl.col("starting_compound").apply(remove_nulls, return_dtype=pl.List(pl.Utf8)).alias("starting_compound"),
# /tmp/ipykernel_1801614/1137062065.py:21: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   pl.col("predicted").apply(remove_nulls, return_dtype=pl.List(pl.Utf8)).alias("predicted")
# shape: (3_435_078, 4)
# ┌────────────────────────┬────────────────────────┬────────────────────────┬───────────────────────┐
# │ reaction_id            ┆ coreactant             ┆ starting_compound      ┆ predicted             │
# │ ---                    ┆ ---                    ┆ ---                    ┆ ---                   │
# │ str                    ┆ list[str]              ┆ list[str]              ┆ list[str]             │
# ╞════════════════════════╪════════════════════════╪════════════════════════╪═══════════════════════╡
# │ Rb9714d47957bd60952782 ┆ ["X731743cee49a2049f3c ┆ ["C24eed3698cfa37e541f ┆ ["C1868bb3f9a58494619 │
# │ 6bf110d6…              ┆ 8c017ce7…              ┆ 254c6cd8…              ┆ 0b8665ef1…            │
# │ R810ee1447f742fc9b0a7b ┆ ["Xed5e87faf61da02132a ┆ ["C0d003ff9f343ef7dc87 ┆ ["C9e2b58f41a6b4a808b │
# │ c698b867…              ┆ 9818e322…              ┆ 2f1beeb0…              ┆ f998f309c…            │
# │ R769d2badf759839719cb1 ┆ ["X731743cee49a2049f3c ┆ ["Cf7c79ac3bd17474b2c4 ┆ ["Cc9c758e98c89d953c3 │
# │ 97d6f9c4…              ┆ 8c017ce7…              ┆ 285adae9…              ┆ c024a1d1a…            │
# │ R5b77bfe7261908be9fe39 ┆ ["X73bc8ef21db580aefe4 ┆ ["C776b2b6f0872d266b36 ┆ ["Cb9f7b1d6537f4d432f │
# │ 632b0688…              ┆ dbc0af17…              ┆ b224113d…              ┆ 397a20c8e…            │
# │ Rc2da26fb1d93d14ef835d ┆ ["X73bc8ef21db580aefe4 ┆ ["C68d986613e1b1f80ed1 ┆ ["C732c2f865caf3d012b │
# │ ce8a5545…              ┆ dbc0af17…              ┆ 342cb895…              ┆ fce675ab7…            │
# │ …                      ┆ …                      ┆ …                      ┆ …                     │
# │ Rbc64174381bbd32d085ca ┆ ["X87786109ddfaf26b1b2 ┆ ["C54707d36d0feb2de5d2 ┆ ["Ccf0af99fa03410632a │
# │ e56b0f58…              ┆ b7f94e18…              ┆ 7b176932…              ┆ 485646282…            │
# │ Rdc5b2880bbe1e9a683e15 ┆ ["X73bc8ef21db580aefe4 ┆ ["C449bb52fd711cb34688 ┆ []                    │
# │ f5f1d9fb…              ┆ dbc0af17…              ┆ 9d46130d…              ┆                       │
# │ Ref3dfad51ff26828aad15 ┆ ["X731743cee49a2049f3c ┆ ["Cdc1cc3dfde2490e1546 ┆ ["Cd7363eeadc6eab2158 │
# │ 43e2501c…              ┆ 8c017ce7…              ┆ a4c81bfb…              ┆ 376e4c967…            │
# │ Rfd062ababfab35e1853d6 ┆ ["X0eb45233dd43ecacb9f ┆ ["C41e842f9ae108bbe657 ┆ ["Cf27a1bfec65e862a7c │
# │ bfdb9d56…              ┆ b1e31140…              ┆ 3aa6f28f…              ┆ 2a30331f6…            │
# │ Rdb3ad733a8da2fd6d034a ┆ ["X73bc8ef21db580aefe4 ┆ ["C875b3b77434fd659fa7 ┆ ["C327ed32a9c48ed69e7 │
# │ 8ff05477…              ┆ dbc0af17…              ┆ 4ab67b65…              ┆ bc193a9ef…            │
# └────────────────────────┴────────────────────────┴────────────────────────┴───────────────────────┘
# shape: (3_435_078, 4)
# ┌────────────────────────┬────────────────────────┬────────────────────────┬───────────────────────┐
# │ reaction_id            ┆ coreactant             ┆ starting_compound      ┆ predicted             │
# │ ---                    ┆ ---                    ┆ ---                    ┆ ---                   │
# │ str                    ┆ list[str]              ┆ list[str]              ┆ list[str]             │
# ╞════════════════════════╪════════════════════════╪════════════════════════╪═══════════════════════╡
# │ Rb9714d47957bd60952782 ┆ [null, "X731743cee49a2 ┆ ["C24eed3698cfa37e541f ┆ [null, null, … null]  │
# │ 6bf110d6…              ┆ 049f3c8c…              ┆ 254c6cd8…              ┆                       │
# │ R810ee1447f742fc9b0a7b ┆ [null, "Xed5e87faf61da ┆ ["C0d003ff9f343ef7dc87 ┆ [null, null, … null]  │
# │ c698b867…              ┆ 02132a98…              ┆ 2f1beeb0…              ┆                       │
# │ R769d2badf759839719cb1 ┆ [null, "X731743cee49a2 ┆ ["Cf7c79ac3bd17474b2c4 ┆ [null, null, … null]  │
# │ 97d6f9c4…              ┆ 049f3c8c…              ┆ 285adae9…              ┆                       │
# │ R5b77bfe7261908be9fe39 ┆ [null, null,           ┆ ["C776b2b6f0872d266b36 ┆ [null, "Cb9f7b1d6537f │
# │ 632b0688…              ┆ "X73bc8ef21db580a…     ┆ b224113d…              ┆ 4d432f397…            │
# │ Rc2da26fb1d93d14ef835d ┆ [null, "X73bc8ef21db58 ┆ ["C68d986613e1b1f80ed1 ┆ [null, null,          │
# │ ce8a5545…              ┆ 0aefe4db…              ┆ 342cb895…              ┆ "C732c2f865caf3d0…    │
# │ …                      ┆ …                      ┆ …                      ┆ …                     │
# │ Rbc64174381bbd32d085ca ┆ [null, "X87786109ddfaf ┆ ["C54707d36d0feb2de5d2 ┆ [null, null, … null]  │
# │ e56b0f58…              ┆ 26b1b2b7…              ┆ 7b176932…              ┆                       │
# │ Rdc5b2880bbe1e9a683e15 ┆ [null, "X73bc8ef21db58 ┆ ["C449bb52fd711cb34688 ┆ [null, null, … null]  │
# │ f5f1d9fb…              ┆ 0aefe4db…              ┆ 9d46130d…              ┆                       │
# │ Ref3dfad51ff26828aad15 ┆ [null, "X731743cee49a2 ┆ ["Cdc1cc3dfde2490e1546 ┆ [null, null, … null]  │
# │ 43e2501c…              ┆ 049f3c8c…              ┆ a4c81bfb…              ┆                       │
# │ Rfd062ababfab35e1853d6 ┆ [null, "X0eb45233dd43e ┆ ["C41e842f9ae108bbe657 ┆ [null, null, … null]  │
# │ bfdb9d56…              ┆ cacb9fb1…              ┆ 3aa6f28f…              ┆                       │
# │ Rdb3ad733a8da2fd6d034a ┆ [null, "X73bc8ef21db58 ┆ ["C875b3b77434fd659fa7 ┆ [null, null, … null]  │
# │ 8ff05477…              ┆ 0aefe4db…              ┆ 4ab67b65…              ┆                       │
# └────────────────────────┴────────────────────────┴────────────────────────┴───────────────────────┘
